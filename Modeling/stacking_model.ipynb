# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sys
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from tqdm.notebook import tqdm
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, ExtraTreesRegressor
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MultiLabelBinarizer
from datetime import datetime


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

# %%
# всегда фиксируйте RANDOM_SEED, чтобы ваши эксперименты были воспроизводимы!
RANDOM_SEED = 42

# %% [markdown]
# # Setup

# %%
VERSION    = 11
#DIR_TRAIN  = '../input/sf-autoru-solve-v4/' # подключил к ноутбуку свой внешний датасет
#DIR_TEST   = '../input/sf-dst-car-price/'
VAL_SIZE   = 0.33   # 33%
N_FOLDS    = 5

# CATBOOST
ITERATIONS = 2000
LR         = 0.1

# %% [markdown]
# # Data

# %%
#cars = pd.read_csv('united_3.csv')
cars = pd.read_csv('cars_new.csv')
#cars.drop(columns=['Unnamed: 0'], inplace=True)
cars.head()
# Out:
#    test style    body    color    fuel    model_date  doors  production_date  \
# 0     0  520i  body 1  color 3  бензин  model date 6      4             1991
# 1     0  316i  body 1  color 1  бензин  model date 7      4             1992
# 2     0  318i  body 1  color 5  бензин  model date 7      4             1994
# 3     0  520i  body 1  color 1  бензин  model date 6      4             1992
# 4     0  520i  body 1  color 1  бензин  model date 6      4             1982
#
#    transmission engine_displacement  engine_power   mileage drive_type  wheel  \
# 0  механическая           eng dis 2           129  300000.0     задний  Левый
# 1  механическая           eng dis 4           102  300000.0     задний  Левый
# 2  механическая           eng dis 5           115  350000.0     задний  Левый
# 3  механическая           eng dis 2           150  100000.0     задний  Левый
# 4  механическая           eng dis 2           125  250000.0     задний  Левый
#
#             condition  owners vehicle_title features    price     tax  \
# 0  Не требует ремонта       3      Оригинал  Unknown  60000.0  4515.0
# 1  Не требует ремонта       3      Дубликат  Unknown  68000.0  2550.0
# 2  Не требует ремонта       3      Дубликат  Unknown  70000.0  2875.0
# 3  Не требует ремонта       3      Оригинал  Unknown  70000.0  5250.0
# 4  Не требует ремонта       1      Оригинал  Unknown  70000.0  3125.0
#
#    tax_per_horse  days_in_use  mileage_per_day  years_in_use
# 0             35        10799        27.780350            29
# 1             25        10434        28.752156            28
# 2             25         9703        36.071318            26
# 3             35        10434         9.584052            28
# 4             25        14086        17.748119            38

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10168 entries, 0 to 10167
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   test                 10168 non-null  int64
#  1   style                10168 non-null  object
#  2   body                 10168 non-null  object
#  3   color                10168 non-null  object
#  4   fuel                 10168 non-null  object
#  5   model_date           10168 non-null  object
#  6   doors                10168 non-null  int64
#  7   production_date      10168 non-null  int64
#  8   transmission         10168 non-null  object
#  9   engine_displacement  10167 non-null  object
#  10  engine_power         10168 non-null  int64
#  11  mileage              10168 non-null  float64
#  12  drive_type           10168 non-null  object
#  13  wheel                10168 non-null  object
#  14  condition            10168 non-null  object
#  15  owners               10168 non-null  int64
#  16  vehicle_title        10168 non-null  object
#  17  features             10168 non-null  object
#  18  price                10168 non-null  float64
#  19  tax                  10168 non-null  float64
#  20  tax_per_horse        10168 non-null  int64
#  21  days_in_use          10168 non-null  int64
#  22  mileage_per_day      10168 non-null  float64
#  23  years_in_use         10168 non-null  int64
# dtypes: float64(4), int64(8), object(12)
# memory usage: 1.9+ MB

# %%
cars['style'] = cars.apply(lambda x: 'Unknown' if pd.isna(x.style) else x.style, axis=1)
cars['engine_displacement'] = cars.apply(lambda x: 'eng dis 1' if pd.isna(x.engine_displacement) else x.engine_displacement, axis=1)

# %%
#перевод категориальных str в int, для методов которым на вход необходимо int.
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MultiLabelBinarizer

le = LabelEncoder()

le.fit(cars['style'])
cars['style'] = le.transform(cars['style'])

le.fit(cars['body'])
cars['body'] = le.transform(cars['body'])


le.fit(cars['color'])
cars['color'] = le.transform(cars['color'])

le.fit(cars['fuel'])
cars['fuel'] = le.transform(cars['fuel'])

le.fit(cars['model_date'])
cars['model_date'] = le.transform(cars['model_date'])

le.fit(cars['transmission'])
cars['transmission'] = le.transform(cars['transmission'])

le.fit(cars['engine_displacement'])
cars['engine_displacement'] = le.transform(cars['engine_displacement'])

le.fit(cars['drive_type'])
cars['drive_type'] = le.transform(cars['drive_type'])

le.fit(cars['wheel'])
cars['wheel'] = le.transform(cars['wheel'])

le.fit(cars['condition'])
cars['condition'] = le.transform(cars['condition'])

le.fit(cars['vehicle_title'])
cars['vehicle_title'] = le.transform(cars['vehicle_title'])

# %%
train = cars[cars['test'] == 0]
train.reset_index(drop=True)
test = cars[cars['test'] == 1]
test.reset_index(drop=True)
sample_submission = pd.read_csv('sample_submission.csv')

# %% [markdown]
# # Data Preprocessing

# %%
def preproc_data(df_input):
    '''includes several functions to pre-process the predictor data.'''
    
    df_output = df_input.copy()
    
    # ################### Предобработка ############################################################## 
    # убираем не нужные для модели признаки
    #df_output.drop(['Таможня', 'Состояние', 'id'], axis=1, inplace=True,)
    
    
    # ################### Feature Engineering ####################################################
    df_output['years_in_use'] = df_output['production_date'].apply(lambda x: datetime.now().year-x) #количество лет использования машины
    
    df_output['mileage_per_day'] = df_output['mileage'] / (df_output['years_in_use'] * 365) #пробег машины в день
    df_output['mileage_per_day'] = df_output.apply(lambda x: x.mileage_per_day if x.years_in_use !=0 else 0, axis=1)
    
    # Переведем комплектацию в dummy-переменные
    #df_output['features'] = df_output.apply(lambda x: '[Unknown]' if x.features == 'Unknown' else x.features, axis=1)
    #df_output['features'] = df_output['features'].apply(lambda x: str(x)[1:-1])
    #df_output['features'] = df_output['features'].apply(lambda x: x.replace("'", ""))
    #features = df_output['features'].str.get_dummies(sep=',')
    #df_output = df_output.join(features)
    
    # ################### fix ############################################################## 
    # Переводим признаки из float в int (иначе catboost выдает ошибку)
    for feature in ['engine_power', 'mileage', 'production_date', 'owners','tax', 'price', 'mileage_per_day']:
        df_output[feature]=df_output[feature].astype('int32')
    #for feature in ['mileage', 'price', 'tax', 'mileage_per_day']:
        #df_output[feature]=df_output[feature].astype('int32')
    
    
    # ################### Clean #################################################### 
    # убираем признаки которые еще не успели обработать, 
    #df_output.drop(['description', 'features', 'test'], axis=1, inplace=True)
    df_output.drop(['features'], axis=1, inplace=True)
    
    return df_output

# %%
train_preproc = preproc_data(train)
X_sub = preproc_data(test)

# %%
X = train_preproc.drop(['price'], axis=1)
y = train_preproc.price.values
X_sub = X_sub.drop(['price'], axis=1)

# %% [markdown]
# # Train Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=VAL_SIZE, shuffle=True, random_state=RANDOM_SEED)

# %% [markdown]
# # CatBoost

# %% [raw]
# Сat features
# CatBoost умеет самостоятельно обрабатывать категориальные признаки, но для корректной обработки нужно их указать:

# %%
# чтобы не писать весь список этих признаков, просто вывел их через nunique(). и так сойдет)
X_train.nunique()
# Out:
# test                      1
# style                   152
# body                      4
# color                     6
# fuel                      3
# model_date                9
# doors                     4
# production_date          36
# transmission              3
# engine_displacement       5
# engine_power             68
# mileage                1614
# drive_type                3
# wheel                     1
# condition                 1
# owners                    3
# vehicle_title             2
# tax                      68
# tax_per_horse             8
# days_in_use              36
# mileage_per_day         152
# years_in_use             36
# dtype: int64

# %%
# Keep list of all categorical features in dataset to specify this for CatBoost
cat_features_ids = np.where(X_train.apply(pd.Series.nunique) < 3000)[0].tolist()

# %%
X_sub.reset_index(drop=True)
# Out:
#       test  style  body  color  fuel  model_date  doors  production_date  \
# 0        1     87     0      0     2           2      4             2017
# 1        1     38     0      0     2           0      4             2019
# 2        1    114     0      0     0           4      4             2012
# 3        1     32     1      0     2           2      5             2015
# 4        1    163     1      0     2           2      5             2019
# ...    ...    ...   ...    ...   ...         ...    ...              ...
# 3832     1     89     0      0     0           1      4             2013
# 3833     1     32     1      0     2           1      5             2016
# 3834     1     95     0      0     0           5      4             2006
# 3835     1     98     0      0     0           4      4             2012
# 3836     1     84     1      0     0           5      5             2010
#
#       transmission  engine_displacement  engine_power  mileage  drive_type  \
# 0                0                    1           190   158836           0
# 1                0                    1           150       10           0
# 2                0                    0           407   120000           2
# 3                0                    0           249   111466           2
# 4                0                    0           381    11891           2
# ...            ...                  ...           ...      ...         ...
# 3832             0                    1           184    98000           0
# 3833             0                    0           249   169615           2
# 3834             0                    3           218   180000           2
# 3835             0                    1           245   137500           2
# 3836             0                    0           407    89905           2
#
#       wheel  condition  owners  vehicle_title    tax  tax_per_horse  \
# 0         0          0       1              1   9500             50
# 1         0          0       1              1   5250             35
# 2         0          0       2              1  61050            150
# 3         0          0       2              1  18675             75
# 4         0          0       1              1  57150            150
# ...     ...        ...     ...            ...    ...            ...
# 3832      0          0       3              1   9200             50
# 3833      0          0       1              1  18675             75
# 3834      0          0       3              1  14170             65
# 3835      0          0       3              1  18375             75
# 3836      0          0       1              1  61050            150
#
#       days_in_use  mileage_per_day  years_in_use
# 0            1302              145             3
# 1             572                0             1
# 2            3129               41             8
# 3            2033               61             5
# 4             572               32             1
# ...           ...              ...           ...
# 3832         2763               38             7
# 3833         1668              116             4
# 3834         5320               35            14
# 3835         3129               47             8
# 3836         3859               24            10
#
# [3837 rows x 22 columns]

# %% [markdown]
# ## Stacking

# %% [markdown]
# Давайте сначала разберемся, что-же такое этот Stacking.
#
# Начнем с Ансамбля моделей:
# Допустим, вы обучили Различные модели. Теперь мы можем просто объединить их предсказания и получить средневзвешенное предсказание по всем моделям. При этом, чем разнообразней модели - тем лучше результат мы получим.
#
# А теперь Stacking:
# У нас есть предсказания от разных моделей, почему бы не использовать их как новые признаки/фитчи и не построить поверх этих предсказаний новую модель? Это основная идея Stacking-a.
#
# Далее его еще можно бесконечно усложнять. Например, добавляя модели обученные на разных выборках и/или с разным составом признаков (bagging), или увеличивая уровни стекинга.

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from collections import defaultdict


def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true))

def print_regression_metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    print(f'RMSE = {rmse:.2f}, MAE = {mae:.2f}, R-sq = {r2:.2f}, MAPE = {mape:.2f} ')

# %%
from sklearn.base import clone
def compute_meta_feature(clf, X_train, X_test, y_train, cv):
    """
    Computes meta-features usinf the classifier cls
    
    :arg model: scikit-learn classifier
    :arg X_train, y_train: training set
    :arg X_test: testing set
    :arg cv: cross-validation folding
    """
    
    X_meta_train = np.zeros_like(y_train, dtype = np.float32)
    X_meta_test = np.zeros(len(X_test), dtype=np.float32)
    for train_fold_index, predict_fold_index in cv.split(X_train):
        X_fold_train, X_fold_predict = X_train[train_fold_index], X_train[predict_fold_index]
        y_fold_train = y_train[train_fold_index]
        
        folded_clf = clone(clf)
        folded_clf.fit(X_fold_train, y_fold_train)
        X_meta_train[predict_fold_index] = folded_clf.predict(X_fold_predict)
        
        print_regression_metrics(X_meta_train[predict_fold_index], y_train[predict_fold_index])
        X_meta_test += folded_clf.predict(X_test)
    
    n = cv.n_splits
    X_meta_test = X_meta_test / n
    
    return X_meta_train, X_meta_test

# %%
def generate_meta_features(regressors, X_train, X_test, y_train, cv):
   
    features = [
        compute_meta_feature(clf, X_train, X_test, y_train, cv)
        for clf in tqdm(regressors)
    ]
    
    stacked_features_train = np.stack([
        features_train for features_train, features_test in features
    ], axis=-1)

    stacked_features_test = np.stack([
        features_test for features_train, features_test in features
    ], axis=-1)
    
    return stacked_features_train, stacked_features_test

# %%
#X = train_preproc.drop(['price'], axis=1)
#y = train_preproc.price.values
#X_sub = X_sub.drop(['price'], axis=1)

#X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size = VAL_SIZE, random_state=RANDOM_SEED)

cv = KFold(n_splits=N_FOLDS, shuffle=True, random_state=42)

def compute_metric(clf, X_train=X_train, y_train=y_train, X_test=X_test):
    clf.fit(X_train, y_train)
    y_test_pred = clf.predict(X_test)
    return print_regression_metrics(y_test, y_test_pred)

# %%
from sklearn.preprocessing import StandardScaler
# Стандартизируем данные:
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
X_sub = scaler.fit_transform(X_sub)

stacked_features_train, stacked_features_test = generate_meta_features([
    RandomForestRegressor(n_estimators=100, random_state=RANDOM_SEED),
    BaggingRegressor(ExtraTreesRegressor(n_estimators=100, random_state=RANDOM_SEED)),
    CatBoostRegressor(loss_function = 'MAE',
                         eval_metric = 'MAPE',
                         learning_rate=0.005,
                         iterations=4500,
                         l2_leaf_reg=2,
                         depth=6,
                         bootstrap_type = 'Bayesian',
                         random_seed=42,
                         od_type='Iter',
                         od_wait=100)
    ], X_train, X_sub, y_train, cv)


#Строим мета-алгоритм

final_model = LinearRegression()
final_model.fit(stacked_features_train, y_train)

# compute_metric(final_model, X_train=stack_future_train, X_test=stack_future_test, y_train=y_train)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# RMSE = 346992.02, MAE = 153914.27, R-sq = 0.91, MAPE = 0.13
# RMSE = 365811.00, MAE = 180178.91, R-sq = 0.87, MAPE = 0.15
# RMSE = 337803.03, MAE = 185668.25, R-sq = 0.92, MAPE = 0.15
# RMSE = 324522.31, MAE = 170072.45, R-sq = 0.92, MAPE = 0.15
# RMSE = 266440.34, MAE = 158020.42, R-sq = 0.94, MAPE = 0.14
# RMSE = 318975.77, MAE = 152684.49, R-sq = 0.93, MAPE = 0.13
# RMSE = 332935.60, MAE = 168185.04, R-sq = 0.89, MAPE = 0.15
# RMSE = 318790.29, MAE = 181186.28, R-sq = 0.93, MAPE = 0.14
# RMSE = 315770.23, MAE = 165397.92, R-sq = 0.92, MAPE = 0.15
# RMSE = 277172.78, MAE = 162291.56, R-sq = 0.94, MAPE = 0.14
# 0:	learn: 0.7904926	total: 6.3ms	remaining: 28.3s
# 1:	learn: 0.7873030	total: 11.2ms	remaining: 25.1s
# 2:	learn: 0.7838232	total: 16ms	remaining: 24s
# 3:	learn: 0.7804052	total: 21ms	remaining: 23.6s
# 4:	learn: 0.7772165	total: 25.7ms	remaining: 23.1s
# 5:	learn: 0.7739279	total: 30.7ms	remaining: 23s
# 6:	learn: 0.7705893	total: 33.9ms	remaining: 21.7s
# 7:	learn: 0.7671651	total: 38.5ms	remaining: 21.6s
# 8:	learn: 0.7638682	total: 43.5ms	remaining: 21.7s
# 9:	learn: 0.7606642	total: 48ms	remaining: 21.5s
# 10:	learn: 0.7574907	total: 52.6ms	remaining: 21.5s
# 11:	learn: 0.7542344	total: 57.5ms	remaining: 21.5s
# 12:	learn: 0.7510557	total: 61.7ms	remaining: 21.3s
# 13:	learn: 0.7480057	total: 66.5ms	remaining: 21.3s
# 14:	learn: 0.7448766	total: 71.2ms	remaining: 21.3s
# 15:	learn: 0.7417788	total: 76ms	remaining: 21.3s
# 16:	learn: 0.7386348	total: 80.3ms	remaining: 21.2s
# 17:	learn: 0.7357607	total: 85.2ms	remaining: 21.2s
# 18:	learn: 0.7327579	total: 90.6ms	remaining: 21.4s
# 19:	learn: 0.7296568	total: 96.2ms	remaining: 21.5s
# 20:	learn: 0.7266127	total: 101ms	remaining: 21.5s
# 21:	learn: 0.7237091	total: 105ms	remaining: 21.5s
# 22:	learn: 0.7207546	total: 109ms	remaining: 21.3s
# 23:	learn: 0.7177295	total: 114ms	remaining: 21.3s
# 24:	learn: 0.7149553	total: 119ms	remaining: 21.3s
# 25:	learn: 0.7118449	total: 124ms	remaining: 21.4s
# 26:	learn: 0.7092432	total: 129ms	remaining: 21.3s
# 27:	learn: 0.7061870	total: 134ms	remaining: 21.4s
# 28:	learn: 0.7032449	total: 139ms	remaining: 21.4s
# 29:	learn: 0.7003985	total: 143ms	remaining: 21.3s
# 30:	learn: 0.6976148	total: 148ms	remaining: 21.3s
# 31:	learn: 0.6947349	total: 152ms	remaining: 21.2s
# 32:	learn: 0.6918970	total: 157ms	remaining: 21.2s
# 33:	learn: 0.6890298	total: 161ms	remaining: 21.2s
# 34:	learn: 0.6862001	total: 166ms	remaining: 21.1s
# 35:	learn: 0.6835473	total: 170ms	remaining: 21.1s
# 36:	learn: 0.6807819	total: 175ms	remaining: 21.1s
# 37:	learn: 0.6780671	total: 181ms	remaining: 21.2s
# 38:	learn: 0.6753273	total: 186ms	remaining: 21.3s
# 39:	learn: 0.6727361	total: 190ms	remaining: 21.2s
# 40:	learn: 0.6700269	total: 195ms	remaining: 21.2s
# 41:	learn: 0.6675452	total: 202ms	remaining: 21.4s
# 42:	learn: 0.6648486	total: 207ms	remaining: 21.5s
# 43:	learn: 0.6622576	total: 212ms	remaining: 21.4s
# 44:	learn: 0.6595485	total: 216ms	remaining: 21.4s
# 45:	learn: 0.6570151	total: 221ms	remaining: 21.4s
# 46:	learn: 0.6545411	total: 226ms	remaining: 21.4s
# 47:	learn: 0.6519525	total: 231ms	remaining: 21.4s
# 48:	learn: 0.6493483	total: 235ms	remaining: 21.4s
# 49:	learn: 0.6467145	total: 239ms	remaining: 21.3s
# 50:	learn: 0.6440785	total: 243ms	remaining: 21.2s
# 51:	learn: 0.6415083	total: 247ms	remaining: 21.1s
# 52:	learn: 0.6388968	total: 251ms	remaining: 21s
# 53:	learn: 0.6364574	total: 254ms	remaining: 20.9s
# 54:	learn: 0.6340603	total: 258ms	remaining: 20.8s
# 55:	learn: 0.6314073	total: 260ms	remaining: 20.7s
# 56:	learn: 0.6289012	total: 263ms	remaining: 20.5s
# 57:	learn: 0.6265596	total: 268ms	remaining: 20.5s
# 58:	learn: 0.6242166	total: 272ms	remaining: 20.5s
# 59:	learn: 0.6218250	total: 277ms	remaining: 20.5s
# 60:	learn: 0.6193959	total: 282ms	remaining: 20.5s
# 61:	learn: 0.6167838	total: 285ms	remaining: 20.4s
# 62:	learn: 0.6143639	total: 288ms	remaining: 20.3s
# 63:	learn: 0.6117265	total: 293ms	remaining: 20.3s
# 64:	learn: 0.6093850	total: 296ms	remaining: 20.2s
# 65:	learn: 0.6070637	total: 299ms	remaining: 20.1s
# 66:	learn: 0.6046375	total: 303ms	remaining: 20s
# 67:	learn: 0.6022504	total: 307ms	remaining: 20s
# 68:	learn: 0.5998501	total: 312ms	remaining: 20s
# 69:	learn: 0.5974852	total: 315ms	remaining: 20s
# 70:	learn: 0.5951157	total: 320ms	remaining: 19.9s
# 71:	learn: 0.5927767	total: 324ms	remaining: 20s
# 72:	learn: 0.5906243	total: 329ms	remaining: 20s
# 73:	learn: 0.5884618	total: 334ms	remaining: 20s
# 74:	learn: 0.5861959	total: 339ms	remaining: 20s
# 75:	learn: 0.5839813	total: 344ms	remaining: 20s
# 76:	learn: 0.5817637	total: 350ms	remaining: 20.1s
# 77:	learn: 0.5793351	total: 354ms	remaining: 20.1s
# 78:	learn: 0.5772070	total: 359ms	remaining: 20.1s
# 79:	learn: 0.5751032	total: 364ms	remaining: 20.1s
# 80:	learn: 0.5729063	total: 369ms	remaining: 20.1s
# 81:	learn: 0.5705941	total: 374ms	remaining: 20.1s
# 82:	learn: 0.5685812	total: 378ms	remaining: 20.1s
# 83:	learn: 0.5664802	total: 383ms	remaining: 20.1s
# 84:	learn: 0.5644148	total: 387ms	remaining: 20.1s
# 85:	learn: 0.5621797	total: 392ms	remaining: 20.1s
# 86:	learn: 0.5600484	total: 398ms	remaining: 20.2s
# 87:	learn: 0.5579185	total: 402ms	remaining: 20.2s
# 88:	learn: 0.5557744	total: 407ms	remaining: 20.1s
# 89:	learn: 0.5535978	total: 411ms	remaining: 20.1s
# 90:	learn: 0.5515339	total: 416ms	remaining: 20.2s
# 91:	learn: 0.5494285	total: 422ms	remaining: 20.2s
# 92:	learn: 0.5472129	total: 427ms	remaining: 20.2s
# 93:	learn: 0.5450712	total: 432ms	remaining: 20.2s
# 94:	learn: 0.5428738	total: 437ms	remaining: 20.3s
# 95:	learn: 0.5408697	total: 442ms	remaining: 20.3s
# 96:	learn: 0.5387759	total: 447ms	remaining: 20.3s
# 97:	learn: 0.5367888	total: 452ms	remaining: 20.3s
# 98:	learn: 0.5347278	total: 456ms	remaining: 20.3s
# 99:	learn: 0.5327283	total: 461ms	remaining: 20.3s
# 100:	learn: 0.5309500	total: 466ms	remaining: 20.3s
# 101:	learn: 0.5292191	total: 471ms	remaining: 20.3s
# 102:	learn: 0.5272032	total: 476ms	remaining: 20.3s
# 103:	learn: 0.5250901	total: 481ms	remaining: 20.3s
# 104:	learn: 0.5231427	total: 484ms	remaining: 20.3s
# 105:	learn: 0.5211332	total: 489ms	remaining: 20.3s
# 106:	learn: 0.5191100	total: 493ms	remaining: 20.2s
# 107:	learn: 0.5173281	total: 497ms	remaining: 20.2s
# 108:	learn: 0.5154340	total: 502ms	remaining: 20.2s
# 109:	learn: 0.5136217	total: 507ms	remaining: 20.2s
# 110:	learn: 0.5117253	total: 512ms	remaining: 20.2s
# 111:	learn: 0.5099648	total: 517ms	remaining: 20.3s
# 112:	learn: 0.5079356	total: 525ms	remaining: 20.4s
# 113:	learn: 0.5061559	total: 530ms	remaining: 20.4s
# 114:	learn: 0.5042503	total: 535ms	remaining: 20.4s
# 115:	learn: 0.5023688	total: 540ms	remaining: 20.4s
# 116:	learn: 0.5005840	total: 544ms	remaining: 20.4s
# 117:	learn: 0.4989213	total: 548ms	remaining: 20.3s
# 118:	learn: 0.4971603	total: 551ms	remaining: 20.3s
# 119:	learn: 0.4953388	total: 556ms	remaining: 20.3s
# 120:	learn: 0.4936896	total: 561ms	remaining: 20.3s
# 121:	learn: 0.4917464	total: 566ms	remaining: 20.3s
# 122:	learn: 0.4900025	total: 570ms	remaining: 20.3s
# 123:	learn: 0.4883149	total: 575ms	remaining: 20.3s
# 124:	learn: 0.4867221	total: 580ms	remaining: 20.3s
# 125:	learn: 0.4849558	total: 585ms	remaining: 20.3s
# 126:	learn: 0.4831719	total: 589ms	remaining: 20.3s
# 127:	learn: 0.4814411	total: 594ms	remaining: 20.3s
# 128:	learn: 0.4796293	total: 599ms	remaining: 20.3s
# 129:	learn: 0.4779000	total: 604ms	remaining: 20.3s
# 130:	learn: 0.4761948	total: 609ms	remaining: 20.3s
# 131:	learn: 0.4745248	total: 613ms	remaining: 20.3s
# 132:	learn: 0.4728756	total: 617ms	remaining: 20.3s
# 133:	learn: 0.4713470	total: 622ms	remaining: 20.3s
# 134:	learn: 0.4695467	total: 626ms	remaining: 20.2s
# 135:	learn: 0.4678438	total: 631ms	remaining: 20.2s
# 136:	learn: 0.4662739	total: 636ms	remaining: 20.2s
# 137:	learn: 0.4645274	total: 640ms	remaining: 20.2s
# 138:	learn: 0.4629551	total: 645ms	remaining: 20.2s
# 139:	learn: 0.4613981	total: 649ms	remaining: 20.2s
# 140:	learn: 0.4598109	total: 654ms	remaining: 20.2s
# 141:	learn: 0.4583045	total: 659ms	remaining: 20.2s
# 142:	learn: 0.4567892	total: 664ms	remaining: 20.2s
# 143:	learn: 0.4553347	total: 669ms	remaining: 20.2s
# 144:	learn: 0.4536975	total: 673ms	remaining: 20.2s
# 145:	learn: 0.4521391	total: 679ms	remaining: 20.2s
# 146:	learn: 0.4505342	total: 688ms	remaining: 20.4s
# 147:	learn: 0.4490556	total: 693ms	remaining: 20.4s
# 148:	learn: 0.4474538	total: 698ms	remaining: 20.4s
# 149:	learn: 0.4458556	total: 702ms	remaining: 20.4s
# 150:	learn: 0.4443960	total: 707ms	remaining: 20.4s
# 151:	learn: 0.4428705	total: 712ms	remaining: 20.4s
# 152:	learn: 0.4414331	total: 716ms	remaining: 20.4s
# 153:	learn: 0.4400350	total: 721ms	remaining: 20.3s
# 154:	learn: 0.4385263	total: 726ms	remaining: 20.3s
# 155:	learn: 0.4370779	total: 731ms	remaining: 20.3s
# 156:	learn: 0.4357045	total: 735ms	remaining: 20.3s
# 157:	learn: 0.4342234	total: 740ms	remaining: 20.3s
# 158:	learn: 0.4327624	total: 745ms	remaining: 20.3s
# 159:	learn: 0.4312328	total: 749ms	remaining: 20.3s
# 160:	learn: 0.4297483	total: 754ms	remaining: 20.3s
# 161:	learn: 0.4282702	total: 759ms	remaining: 20.3s
# 162:	learn: 0.4268628	total: 764ms	remaining: 20.3s
# 163:	learn: 0.4254499	total: 768ms	remaining: 20.3s
# 164:	learn: 0.4240955	total: 774ms	remaining: 20.3s
# 165:	learn: 0.4226855	total: 778ms	remaining: 20.3s
# 166:	learn: 0.4212394	total: 783ms	remaining: 20.3s
# 167:	learn: 0.4197248	total: 788ms	remaining: 20.3s
# 168:	learn: 0.4184160	total: 792ms	remaining: 20.3s
# 169:	learn: 0.4171993	total: 797ms	remaining: 20.3s
# 170:	learn: 0.4158851	total: 801ms	remaining: 20.3s
# 171:	learn: 0.4144809	total: 806ms	remaining: 20.3s
# 172:	learn: 0.4132291	total: 811ms	remaining: 20.3s
# 173:	learn: 0.4119898	total: 816ms	remaining: 20.3s
# 174:	learn: 0.4107297	total: 821ms	remaining: 20.3s
# 175:	learn: 0.4094153	total: 827ms	remaining: 20.3s
# 176:	learn: 0.4081000	total: 831ms	remaining: 20.3s
# 177:	learn: 0.4067438	total: 836ms	remaining: 20.3s
# 178:	learn: 0.4055744	total: 841ms	remaining: 20.3s
# 179:	learn: 0.4041314	total: 847ms	remaining: 20.3s
# 180:	learn: 0.4027931	total: 851ms	remaining: 20.3s
# 181:	learn: 0.4013679	total: 856ms	remaining: 20.3s
# 182:	learn: 0.3999422	total: 861ms	remaining: 20.3s
# 183:	learn: 0.3985386	total: 865ms	remaining: 20.3s
# 184:	learn: 0.3972221	total: 870ms	remaining: 20.3s
# 185:	learn: 0.3960549	total: 875ms	remaining: 20.3s
# 186:	learn: 0.3947052	total: 879ms	remaining: 20.3s
# 187:	learn: 0.3934578	total: 884ms	remaining: 20.3s
# 188:	learn: 0.3923596	total: 889ms	remaining: 20.3s
# 189:	learn: 0.3910246	total: 893ms	remaining: 20.3s
# 190:	learn: 0.3899243	total: 898ms	remaining: 20.3s
# 191:	learn: 0.3886925	total: 903ms	remaining: 20.3s
# 192:	learn: 0.3874534	total: 907ms	remaining: 20.3s
# 193:	learn: 0.3862361	total: 912ms	remaining: 20.2s
# 194:	learn: 0.3851194	total: 917ms	remaining: 20.2s
# 195:	learn: 0.3839370	total: 921ms	remaining: 20.2s
# 196:	learn: 0.3826321	total: 926ms	remaining: 20.2s
# 197:	learn: 0.3813831	total: 931ms	remaining: 20.2s
# 198:	learn: 0.3800992	total: 935ms	remaining: 20.2s
# 199:	learn: 0.3790338	total: 940ms	remaining: 20.2s
# 200:	learn: 0.3778212	total: 945ms	remaining: 20.2s
# 201:	learn: 0.3766015	total: 950ms	remaining: 20.2s
# 202:	learn: 0.3755511	total: 954ms	remaining: 20.2s
# 203:	learn: 0.3743556	total: 960ms	remaining: 20.2s
# 204:	learn: 0.3731764	total: 965ms	remaining: 20.2s
# 205:	learn: 0.3719044	total: 971ms	remaining: 20.2s
# 206:	learn: 0.3707280	total: 976ms	remaining: 20.2s
# 207:	learn: 0.3695562	total: 982ms	remaining: 20.3s
# 208:	learn: 0.3684256	total: 986ms	remaining: 20.3s
# 209:	learn: 0.3673074	total: 991ms	remaining: 20.3s
# 210:	learn: 0.3662314	total: 996ms	remaining: 20.3s
# 211:	learn: 0.3651441	total: 1s	remaining: 20.3s
# 212:	learn: 0.3639824	total: 1.01s	remaining: 20.3s
# 213:	learn: 0.3627884	total: 1.01s	remaining: 20.3s
# 214:	learn: 0.3615739	total: 1.02s	remaining: 20.3s
# 215:	learn: 0.3604595	total: 1.02s	remaining: 20.3s
# 216:	learn: 0.3593547	total: 1.03s	remaining: 20.3s
# 217:	learn: 0.3582279	total: 1.03s	remaining: 20.3s
# 218:	learn: 0.3570539	total: 1.03s	remaining: 20.2s
# 219:	learn: 0.3560260	total: 1.04s	remaining: 20.2s
# 220:	learn: 0.3549917	total: 1.04s	remaining: 20.2s
# 221:	learn: 0.3538147	total: 1.05s	remaining: 20.2s
# 222:	learn: 0.3528000	total: 1.05s	remaining: 20.2s
# 223:	learn: 0.3516216	total: 1.06s	remaining: 20.2s
# 224:	learn: 0.3504519	total: 1.07s	remaining: 20.3s
# 225:	learn: 0.3494601	total: 1.07s	remaining: 20.3s
# 226:	learn: 0.3484317	total: 1.08s	remaining: 20.3s
# 227:	learn: 0.3473147	total: 1.08s	remaining: 20.3s
# 228:	learn: 0.3462729	total: 1.09s	remaining: 20.3s
# 229:	learn: 0.3453203	total: 1.09s	remaining: 20.2s
# 230:	learn: 0.3441900	total: 1.09s	remaining: 20.2s
# 231:	learn: 0.3431742	total: 1.1s	remaining: 20.2s
# 232:	learn: 0.3420176	total: 1.1s	remaining: 20.2s
# 233:	learn: 0.3409478	total: 1.11s	remaining: 20.2s
# 234:	learn: 0.3399134	total: 1.11s	remaining: 20.2s
# 235:	learn: 0.3388510	total: 1.12s	remaining: 20.2s
# 236:	learn: 0.3379247	total: 1.12s	remaining: 20.2s
# 237:	learn: 0.3368558	total: 1.13s	remaining: 20.2s
# 238:	learn: 0.3357995	total: 1.13s	remaining: 20.2s
# 239:	learn: 0.3348477	total: 1.14s	remaining: 20.2s
# 240:	learn: 0.3338562	total: 1.14s	remaining: 20.2s
# 241:	learn: 0.3329396	total: 1.15s	remaining: 20.2s
# 242:	learn: 0.3319069	total: 1.15s	remaining: 20.2s
# 243:	learn: 0.3309352	total: 1.16s	remaining: 20.2s
# 244:	learn: 0.3298466	total: 1.16s	remaining: 20.2s
# 245:	learn: 0.3288358	total: 1.17s	remaining: 20.2s
# 246:	learn: 0.3278140	total: 1.17s	remaining: 20.2s
# 247:	learn: 0.3268755	total: 1.18s	remaining: 20.2s
# 248:	learn: 0.3259671	total: 1.18s	remaining: 20.2s
# 249:	learn: 0.3249554	total: 1.19s	remaining: 20.2s
# 250:	learn: 0.3240206	total: 1.19s	remaining: 20.2s
# 251:	learn: 0.3230685	total: 1.2s	remaining: 20.2s
# 252:	learn: 0.3221290	total: 1.2s	remaining: 20.1s
# 253:	learn: 0.3211978	total: 1.2s	remaining: 20.1s
# 254:	learn: 0.3202369	total: 1.21s	remaining: 20.1s
# 255:	learn: 0.3193566	total: 1.21s	remaining: 20.1s
# 256:	learn: 0.3184117	total: 1.22s	remaining: 20.1s
# 257:	learn: 0.3176576	total: 1.22s	remaining: 20.1s
# 258:	learn: 0.3167789	total: 1.23s	remaining: 20.1s
# 259:	learn: 0.3159062	total: 1.23s	remaining: 20.1s
# 260:	learn: 0.3150927	total: 1.24s	remaining: 20.1s
# 261:	learn: 0.3142785	total: 1.24s	remaining: 20.1s
# 262:	learn: 0.3133797	total: 1.25s	remaining: 20.1s
# 263:	learn: 0.3125078	total: 1.25s	remaining: 20.1s
# 264:	learn: 0.3116369	total: 1.26s	remaining: 20.1s
# 265:	learn: 0.3107213	total: 1.26s	remaining: 20.1s
# 266:	learn: 0.3099279	total: 1.26s	remaining: 20.1s
# 267:	learn: 0.3091128	total: 1.27s	remaining: 20.1s
# 268:	learn: 0.3082206	total: 1.27s	remaining: 20.1s
# 269:	learn: 0.3074703	total: 1.28s	remaining: 20s
# 270:	learn: 0.3066827	total: 1.28s	remaining: 20s
# 271:	learn: 0.3058544	total: 1.29s	remaining: 20s
# 272:	learn: 0.3051232	total: 1.29s	remaining: 20s
# 273:	learn: 0.3042039	total: 1.3s	remaining: 20s
# 274:	learn: 0.3033197	total: 1.3s	remaining: 20s
# 275:	learn: 0.3025143	total: 1.31s	remaining: 20s
# 276:	learn: 0.3016358	total: 1.31s	remaining: 20s
# 277:	learn: 0.3007663	total: 1.32s	remaining: 20s
# 278:	learn: 0.2999029	total: 1.32s	remaining: 20s
# 279:	learn: 0.2990502	total: 1.32s	remaining: 20s
# 280:	learn: 0.2981670	total: 1.33s	remaining: 20s
# 281:	learn: 0.2973579	total: 1.33s	remaining: 20s
# 282:	learn: 0.2966521	total: 1.34s	remaining: 20s
# 283:	learn: 0.2958385	total: 1.34s	remaining: 20s
# 284:	learn: 0.2950320	total: 1.35s	remaining: 20s
# 285:	learn: 0.2942808	total: 1.35s	remaining: 20s
# 286:	learn: 0.2935284	total: 1.36s	remaining: 19.9s
# 287:	learn: 0.2928048	total: 1.36s	remaining: 19.9s
# 288:	learn: 0.2920126	total: 1.37s	remaining: 19.9s
# 289:	learn: 0.2912315	total: 1.37s	remaining: 19.9s
# 290:	learn: 0.2905622	total: 1.38s	remaining: 19.9s
# 291:	learn: 0.2897898	total: 1.38s	remaining: 19.9s
# 292:	learn: 0.2889208	total: 1.39s	remaining: 19.9s
# 293:	learn: 0.2882347	total: 1.39s	remaining: 19.9s
# 294:	learn: 0.2874437	total: 1.4s	remaining: 19.9s
# 295:	learn: 0.2866951	total: 1.4s	remaining: 19.9s
# 296:	learn: 0.2859016	total: 1.4s	remaining: 19.9s
# 297:	learn: 0.2850792	total: 1.41s	remaining: 19.9s
# 298:	learn: 0.2842699	total: 1.41s	remaining: 19.9s
# 299:	learn: 0.2834373	total: 1.42s	remaining: 19.9s
# 300:	learn: 0.2826632	total: 1.42s	remaining: 19.9s
# 301:	learn: 0.2819030	total: 1.43s	remaining: 19.8s
# 302:	learn: 0.2812454	total: 1.43s	remaining: 19.8s
# 303:	learn: 0.2806069	total: 1.44s	remaining: 19.8s
# 304:	learn: 0.2798454	total: 1.44s	remaining: 19.8s
# 305:	learn: 0.2790914	total: 1.45s	remaining: 19.8s
# 306:	learn: 0.2782989	total: 1.45s	remaining: 19.8s
# 307:	learn: 0.2775244	total: 1.46s	remaining: 19.8s
# 308:	learn: 0.2768606	total: 1.46s	remaining: 19.8s
# 309:	learn: 0.2761443	total: 1.46s	remaining: 19.8s
# 310:	learn: 0.2753837	total: 1.47s	remaining: 19.8s
# 311:	learn: 0.2747209	total: 1.47s	remaining: 19.8s
# 312:	learn: 0.2739845	total: 1.48s	remaining: 19.8s
# 313:	learn: 0.2732408	total: 1.48s	remaining: 19.8s
# 314:	learn: 0.2725160	total: 1.49s	remaining: 19.8s
# 315:	learn: 0.2718903	total: 1.49s	remaining: 19.7s
# 316:	learn: 0.2712293	total: 1.5s	remaining: 19.7s
# 317:	learn: 0.2705575	total: 1.5s	remaining: 19.7s
# 318:	learn: 0.2698825	total: 1.5s	remaining: 19.7s
# 319:	learn: 0.2692404	total: 1.51s	remaining: 19.7s
# 320:	learn: 0.2685514	total: 1.51s	remaining: 19.7s
# 321:	learn: 0.2679241	total: 1.52s	remaining: 19.7s
# 322:	learn: 0.2672250	total: 1.52s	remaining: 19.7s
# 323:	learn: 0.2665998	total: 1.53s	remaining: 19.7s
# 324:	learn: 0.2660084	total: 1.53s	remaining: 19.7s
# 325:	learn: 0.2653278	total: 1.54s	remaining: 19.7s
# 326:	learn: 0.2646526	total: 1.54s	remaining: 19.7s
# 327:	learn: 0.2640540	total: 1.55s	remaining: 19.7s
# 328:	learn: 0.2633474	total: 1.55s	remaining: 19.7s
# 329:	learn: 0.2627878	total: 1.56s	remaining: 19.7s
# 330:	learn: 0.2622026	total: 1.56s	remaining: 19.7s
# 331:	learn: 0.2615623	total: 1.57s	remaining: 19.7s
# 332:	learn: 0.2609881	total: 1.57s	remaining: 19.7s
# 333:	learn: 0.2603563	total: 1.58s	remaining: 19.7s
# 334:	learn: 0.2597102	total: 1.58s	remaining: 19.7s
# 335:	learn: 0.2591165	total: 1.59s	remaining: 19.7s
# 336:	learn: 0.2584924	total: 1.59s	remaining: 19.7s
# 337:	learn: 0.2579916	total: 1.6s	remaining: 19.7s
# 338:	learn: 0.2573724	total: 1.6s	remaining: 19.7s
# 339:	learn: 0.2568344	total: 1.61s	remaining: 19.7s
# 340:	learn: 0.2562925	total: 1.61s	remaining: 19.6s
# 341:	learn: 0.2556640	total: 1.61s	remaining: 19.6s
# 342:	learn: 0.2550861	total: 1.62s	remaining: 19.6s
# 343:	learn: 0.2544641	total: 1.62s	remaining: 19.6s
# 344:	learn: 0.2538535	total: 1.63s	remaining: 19.6s
# 345:	learn: 0.2532458	total: 1.63s	remaining: 19.6s
# 346:	learn: 0.2526672	total: 1.64s	remaining: 19.6s
# 347:	learn: 0.2521300	total: 1.64s	remaining: 19.6s
# 348:	learn: 0.2514826	total: 1.65s	remaining: 19.6s
# 349:	learn: 0.2509628	total: 1.65s	remaining: 19.6s
# 350:	learn: 0.2503594	total: 1.66s	remaining: 19.6s
# 351:	learn: 0.2497451	total: 1.66s	remaining: 19.6s
# 352:	learn: 0.2492309	total: 1.67s	remaining: 19.6s
# 353:	learn: 0.2487209	total: 1.67s	remaining: 19.6s
# 354:	learn: 0.2481593	total: 1.68s	remaining: 19.6s
# 355:	learn: 0.2475920	total: 1.68s	remaining: 19.6s
# 356:	learn: 0.2470055	total: 1.69s	remaining: 19.6s
# 357:	learn: 0.2465606	total: 1.69s	remaining: 19.6s
# 358:	learn: 0.2460091	total: 1.7s	remaining: 19.6s
# 359:	learn: 0.2455369	total: 1.7s	remaining: 19.6s
# 360:	learn: 0.2449251	total: 1.71s	remaining: 19.6s
# 361:	learn: 0.2444162	total: 1.71s	remaining: 19.5s
# 362:	learn: 0.2439898	total: 1.71s	remaining: 19.5s
# 363:	learn: 0.2433932	total: 1.72s	remaining: 19.5s
# 364:	learn: 0.2428892	total: 1.72s	remaining: 19.5s
# 365:	learn: 0.2423190	total: 1.73s	remaining: 19.5s
# 366:	learn: 0.2418311	total: 1.73s	remaining: 19.5s
# 367:	learn: 0.2412809	total: 1.74s	remaining: 19.5s
# 368:	learn: 0.2407321	total: 1.74s	remaining: 19.5s
# 369:	learn: 0.2401995	total: 1.75s	remaining: 19.5s
# 370:	learn: 0.2396718	total: 1.75s	remaining: 19.5s
# 371:	learn: 0.2391349	total: 1.76s	remaining: 19.5s
# 372:	learn: 0.2386639	total: 1.76s	remaining: 19.5s
# 373:	learn: 0.2381588	total: 1.77s	remaining: 19.5s
# 374:	learn: 0.2376920	total: 1.77s	remaining: 19.5s
# 375:	learn: 0.2371559	total: 1.77s	remaining: 19.5s
# 376:	learn: 0.2366636	total: 1.78s	remaining: 19.5s
# 377:	learn: 0.2361344	total: 1.78s	remaining: 19.5s
# 378:	learn: 0.2356567	total: 1.79s	remaining: 19.5s
# 379:	learn: 0.2351640	total: 1.79s	remaining: 19.4s
# 380:	learn: 0.2346350	total: 1.8s	remaining: 19.4s
# 381:	learn: 0.2341161	total: 1.8s	remaining: 19.4s
# 382:	learn: 0.2337131	total: 1.8s	remaining: 19.4s
# 383:	learn: 0.2332513	total: 1.81s	remaining: 19.4s
# 384:	learn: 0.2327705	total: 1.81s	remaining: 19.4s
# 385:	learn: 0.2322485	total: 1.81s	remaining: 19.3s
# 386:	learn: 0.2317430	total: 1.82s	remaining: 19.3s
# 387:	learn: 0.2314543	total: 1.82s	remaining: 19.3s
# 388:	learn: 0.2309689	total: 1.82s	remaining: 19.3s
# 389:	learn: 0.2305997	total: 1.83s	remaining: 19.3s
# 390:	learn: 0.2300814	total: 1.83s	remaining: 19.2s
# 391:	learn: 0.2296896	total: 1.83s	remaining: 19.2s
# 392:	learn: 0.2292450	total: 1.84s	remaining: 19.2s
# 393:	learn: 0.2288150	total: 1.84s	remaining: 19.2s
# 394:	learn: 0.2283164	total: 1.84s	remaining: 19.2s
# 395:	learn: 0.2279170	total: 1.84s	remaining: 19.1s
# 396:	learn: 0.2274943	total: 1.85s	remaining: 19.1s
# 397:	learn: 0.2270030	total: 1.85s	remaining: 19.1s
# 398:	learn: 0.2265771	total: 1.86s	remaining: 19.1s
# 399:	learn: 0.2260860	total: 1.86s	remaining: 19.1s
# 400:	learn: 0.2256107	total: 1.86s	remaining: 19.1s
# 401:	learn: 0.2251814	total: 1.87s	remaining: 19s
# 402:	learn: 0.2247270	total: 1.87s	remaining: 19s
# 403:	learn: 0.2243020	total: 1.88s	remaining: 19s
# 404:	learn: 0.2239632	total: 1.88s	remaining: 19s
# 405:	learn: 0.2235206	total: 1.88s	remaining: 19s
# 406:	learn: 0.2231144	total: 1.88s	remaining: 18.9s
# 407:	learn: 0.2226588	total: 1.89s	remaining: 18.9s
# 408:	learn: 0.2222351	total: 1.89s	remaining: 18.9s
# 409:	learn: 0.2217779	total: 1.89s	remaining: 18.9s
# 410:	learn: 0.2213015	total: 1.89s	remaining: 18.8s
# 411:	learn: 0.2208829	total: 1.9s	remaining: 18.8s
# 412:	learn: 0.2204512	total: 1.9s	remaining: 18.8s
# 413:	learn: 0.2200645	total: 1.9s	remaining: 18.8s
# 414:	learn: 0.2196999	total: 1.91s	remaining: 18.8s
# 415:	learn: 0.2192803	total: 1.91s	remaining: 18.7s
# 416:	learn: 0.2188384	total: 1.91s	remaining: 18.7s
# 417:	learn: 0.2184073	total: 1.91s	remaining: 18.7s
# 418:	learn: 0.2180083	total: 1.92s	remaining: 18.7s
# 419:	learn: 0.2176148	total: 1.92s	remaining: 18.7s
# 420:	learn: 0.2171935	total: 1.92s	remaining: 18.6s
# 421:	learn: 0.2167770	total: 1.93s	remaining: 18.6s
# 422:	learn: 0.2164001	total: 1.93s	remaining: 18.6s
# 423:	learn: 0.2159697	total: 1.93s	remaining: 18.6s
# 424:	learn: 0.2156047	total: 1.93s	remaining: 18.5s
# 425:	learn: 0.2151910	total: 1.94s	remaining: 18.5s
# 426:	learn: 0.2147828	total: 1.94s	remaining: 18.5s
# 427:	learn: 0.2144068	total: 1.94s	remaining: 18.5s
# 428:	learn: 0.2140967	total: 1.95s	remaining: 18.5s
# 429:	learn: 0.2137228	total: 1.95s	remaining: 18.5s
# 430:	learn: 0.2133626	total: 1.96s	remaining: 18.5s
# 431:	learn: 0.2129864	total: 1.96s	remaining: 18.5s
# 432:	learn: 0.2126229	total: 1.96s	remaining: 18.4s
# 433:	learn: 0.2122387	total: 1.97s	remaining: 18.4s
# 434:	learn: 0.2118735	total: 1.97s	remaining: 18.4s
# 435:	learn: 0.2114948	total: 1.97s	remaining: 18.4s
# 436:	learn: 0.2111064	total: 1.98s	remaining: 18.4s
# 437:	learn: 0.2107562	total: 1.98s	remaining: 18.4s
# 438:	learn: 0.2103153	total: 1.98s	remaining: 18.3s
# 439:	learn: 0.2099031	total: 1.99s	remaining: 18.3s
# 440:	learn: 0.2095800	total: 1.99s	remaining: 18.3s
# 441:	learn: 0.2091961	total: 2s	remaining: 18.3s
# 442:	learn: 0.2088127	total: 2s	remaining: 18.3s
# 443:	learn: 0.2084224	total: 2s	remaining: 18.3s
# 444:	learn: 0.2080443	total: 2.01s	remaining: 18.3s
# 445:	learn: 0.2076855	total: 2.01s	remaining: 18.3s
# 446:	learn: 0.2073138	total: 2.02s	remaining: 18.3s
# 447:	learn: 0.2069351	total: 2.02s	remaining: 18.3s
# 448:	learn: 0.2065696	total: 2.03s	remaining: 18.3s
# 449:	learn: 0.2061796	total: 2.03s	remaining: 18.3s
# 450:	learn: 0.2058474	total: 2.03s	remaining: 18.3s
# 451:	learn: 0.2055452	total: 2.04s	remaining: 18.3s
# 452:	learn: 0.2052309	total: 2.04s	remaining: 18.2s
# 453:	learn: 0.2048921	total: 2.04s	remaining: 18.2s
# 454:	learn: 0.2046301	total: 2.05s	remaining: 18.2s
# 455:	learn: 0.2043040	total: 2.05s	remaining: 18.2s
# 456:	learn: 0.2039673	total: 2.06s	remaining: 18.2s
# 457:	learn: 0.2035986	total: 2.06s	remaining: 18.2s
# 458:	learn: 0.2032566	total: 2.06s	remaining: 18.2s
# 459:	learn: 0.2028959	total: 2.07s	remaining: 18.2s
# 460:	learn: 0.2025441	total: 2.07s	remaining: 18.2s
# 461:	learn: 0.2022003	total: 2.08s	remaining: 18.2s
# 462:	learn: 0.2018681	total: 2.08s	remaining: 18.2s
# 463:	learn: 0.2015090	total: 2.09s	remaining: 18.2s
# 464:	learn: 0.2011802	total: 2.09s	remaining: 18.1s
# 465:	learn: 0.2008435	total: 2.1s	remaining: 18.1s
# 466:	learn: 0.2004893	total: 2.1s	remaining: 18.1s
# 467:	learn: 0.2001544	total: 2.1s	remaining: 18.1s
# 468:	learn: 0.1998675	total: 2.11s	remaining: 18.1s
# 469:	learn: 0.1995514	total: 2.11s	remaining: 18.1s
# 470:	learn: 0.1992635	total: 2.12s	remaining: 18.1s
# 471:	learn: 0.1989107	total: 2.12s	remaining: 18.1s
# 472:	learn: 0.1986006	total: 2.12s	remaining: 18.1s
# 473:	learn: 0.1982768	total: 2.13s	remaining: 18.1s
# 474:	learn: 0.1979747	total: 2.13s	remaining: 18.1s
# 475:	learn: 0.1976695	total: 2.14s	remaining: 18.1s
# 476:	learn: 0.1973876	total: 2.14s	remaining: 18.1s
# 477:	learn: 0.1970780	total: 2.15s	remaining: 18.1s
# 478:	learn: 0.1967541	total: 2.15s	remaining: 18.1s
# 479:	learn: 0.1964503	total: 2.16s	remaining: 18.1s
# 480:	learn: 0.1961600	total: 2.16s	remaining: 18.1s
# 481:	learn: 0.1958954	total: 2.17s	remaining: 18.1s
# 482:	learn: 0.1955818	total: 2.17s	remaining: 18.1s
# 483:	learn: 0.1952508	total: 2.18s	remaining: 18.1s
# 484:	learn: 0.1949686	total: 2.18s	remaining: 18.1s
# 485:	learn: 0.1947109	total: 2.19s	remaining: 18.1s
# 486:	learn: 0.1944131	total: 2.19s	remaining: 18s
# 487:	learn: 0.1941037	total: 2.19s	remaining: 18s
# 488:	learn: 0.1938278	total: 2.19s	remaining: 18s
# 489:	learn: 0.1935943	total: 2.2s	remaining: 18s
# 490:	learn: 0.1933149	total: 2.2s	remaining: 18s
# 491:	learn: 0.1929900	total: 2.21s	remaining: 18s
# 492:	learn: 0.1927110	total: 2.21s	remaining: 18s
# 493:	learn: 0.1924064	total: 2.21s	remaining: 18s
# 494:	learn: 0.1920814	total: 2.22s	remaining: 18s
# 495:	learn: 0.1917791	total: 2.23s	remaining: 18s
# 496:	learn: 0.1914975	total: 2.23s	remaining: 18s
# 497:	learn: 0.1912113	total: 2.24s	remaining: 18s
# 498:	learn: 0.1909681	total: 2.25s	remaining: 18s
# 499:	learn: 0.1906671	total: 2.25s	remaining: 18s
# 500:	learn: 0.1903691	total: 2.26s	remaining: 18s
# 501:	learn: 0.1901015	total: 2.26s	remaining: 18s
# 502:	learn: 0.1898690	total: 2.27s	remaining: 18s
# 503:	learn: 0.1895709	total: 2.27s	remaining: 18s
# 504:	learn: 0.1892657	total: 2.27s	remaining: 18s
# 505:	learn: 0.1890630	total: 2.28s	remaining: 18s
# 506:	learn: 0.1887795	total: 2.28s	remaining: 18s
# 507:	learn: 0.1885030	total: 2.29s	remaining: 18s
# 508:	learn: 0.1883003	total: 2.29s	remaining: 18s
# 509:	learn: 0.1880944	total: 2.3s	remaining: 18s
# 510:	learn: 0.1878225	total: 2.3s	remaining: 18s
# 511:	learn: 0.1875508	total: 2.31s	remaining: 18s
# 512:	learn: 0.1872613	total: 2.31s	remaining: 18s
# 513:	learn: 0.1870261	total: 2.32s	remaining: 18s
# 514:	learn: 0.1867962	total: 2.32s	remaining: 18s
# 515:	learn: 0.1865927	total: 2.33s	remaining: 18s
# 516:	learn: 0.1863755	total: 2.33s	remaining: 18s
# 517:	learn: 0.1861217	total: 2.34s	remaining: 18s
# 518:	learn: 0.1858779	total: 2.34s	remaining: 18s
# 519:	learn: 0.1856169	total: 2.35s	remaining: 18s
# 520:	learn: 0.1854251	total: 2.35s	remaining: 18s
# 521:	learn: 0.1851818	total: 2.35s	remaining: 17.9s
# 522:	learn: 0.1849402	total: 2.36s	remaining: 17.9s
# 523:	learn: 0.1846686	total: 2.36s	remaining: 17.9s
# 524:	learn: 0.1844274	total: 2.37s	remaining: 17.9s
# 525:	learn: 0.1841853	total: 2.37s	remaining: 17.9s
# 526:	learn: 0.1840134	total: 2.38s	remaining: 17.9s
# 527:	learn: 0.1838044	total: 2.38s	remaining: 17.9s
# 528:	learn: 0.1835470	total: 2.38s	remaining: 17.9s
# 529:	learn: 0.1833084	total: 2.39s	remaining: 17.9s
# 530:	learn: 0.1831590	total: 2.39s	remaining: 17.9s
# 531:	learn: 0.1829166	total: 2.4s	remaining: 17.9s
# 532:	learn: 0.1826930	total: 2.4s	remaining: 17.9s
# 533:	learn: 0.1824589	total: 2.41s	remaining: 17.9s
# 534:	learn: 0.1822273	total: 2.41s	remaining: 17.9s
# 535:	learn: 0.1820239	total: 2.42s	remaining: 17.9s
# 536:	learn: 0.1818341	total: 2.42s	remaining: 17.9s
# 537:	learn: 0.1816181	total: 2.42s	remaining: 17.9s
# 538:	learn: 0.1813918	total: 2.43s	remaining: 17.9s
# 539:	learn: 0.1811439	total: 2.43s	remaining: 17.9s
# 540:	learn: 0.1809702	total: 2.44s	remaining: 17.9s
# 541:	learn: 0.1807379	total: 2.44s	remaining: 17.8s
# 542:	learn: 0.1805375	total: 2.45s	remaining: 17.8s
# 543:	learn: 0.1803081	total: 2.45s	remaining: 17.8s
# 544:	learn: 0.1801389	total: 2.46s	remaining: 17.8s
# 545:	learn: 0.1799089	total: 2.46s	remaining: 17.8s
# 546:	learn: 0.1796980	total: 2.47s	remaining: 17.8s
# 547:	learn: 0.1795168	total: 2.47s	remaining: 17.8s
# 548:	learn: 0.1793205	total: 2.48s	remaining: 17.8s
# 549:	learn: 0.1790955	total: 2.48s	remaining: 17.8s
# 550:	learn: 0.1788444	total: 2.48s	remaining: 17.8s
# 551:	learn: 0.1786584	total: 2.49s	remaining: 17.8s
# 552:	learn: 0.1784959	total: 2.49s	remaining: 17.8s
# 553:	learn: 0.1782912	total: 2.5s	remaining: 17.8s
# 554:	learn: 0.1780928	total: 2.5s	remaining: 17.8s
# 555:	learn: 0.1779092	total: 2.51s	remaining: 17.8s
# 556:	learn: 0.1777464	total: 2.51s	remaining: 17.8s
# 557:	learn: 0.1775932	total: 2.52s	remaining: 17.8s
# 558:	learn: 0.1773917	total: 2.52s	remaining: 17.8s
# 559:	learn: 0.1772201	total: 2.52s	remaining: 17.8s
# 560:	learn: 0.1770315	total: 2.53s	remaining: 17.8s
# 561:	learn: 0.1768446	total: 2.53s	remaining: 17.8s
# 562:	learn: 0.1766508	total: 2.54s	remaining: 17.8s
# 563:	learn: 0.1765166	total: 2.54s	remaining: 17.7s
# 564:	learn: 0.1763117	total: 2.55s	remaining: 17.7s
# 565:	learn: 0.1761093	total: 2.55s	remaining: 17.7s
# 566:	learn: 0.1759467	total: 2.56s	remaining: 17.7s
# 567:	learn: 0.1757502	total: 2.56s	remaining: 17.7s
# 568:	learn: 0.1755749	total: 2.56s	remaining: 17.7s
# 569:	learn: 0.1753788	total: 2.57s	remaining: 17.7s
# 570:	learn: 0.1751923	total: 2.58s	remaining: 17.7s
# 571:	learn: 0.1749842	total: 2.58s	remaining: 17.7s
# 572:	learn: 0.1747957	total: 2.58s	remaining: 17.7s
# 573:	learn: 0.1745885	total: 2.59s	remaining: 17.7s
# 574:	learn: 0.1743853	total: 2.59s	remaining: 17.7s
# 575:	learn: 0.1742545	total: 2.6s	remaining: 17.7s
# 576:	learn: 0.1740520	total: 2.6s	remaining: 17.7s
# 577:	learn: 0.1738810	total: 2.61s	remaining: 17.7s
# 578:	learn: 0.1736965	total: 2.61s	remaining: 17.7s
# 579:	learn: 0.1734998	total: 2.62s	remaining: 17.7s
# 580:	learn: 0.1733214	total: 2.62s	remaining: 17.7s
# 581:	learn: 0.1731182	total: 2.63s	remaining: 17.7s
# 582:	learn: 0.1729078	total: 2.63s	remaining: 17.7s
# 583:	learn: 0.1727165	total: 2.63s	remaining: 17.7s
# 584:	learn: 0.1725705	total: 2.64s	remaining: 17.7s
# 585:	learn: 0.1724112	total: 2.64s	remaining: 17.7s
# 586:	learn: 0.1722392	total: 2.65s	remaining: 17.7s
# 587:	learn: 0.1720318	total: 2.65s	remaining: 17.7s
# 588:	learn: 0.1718471	total: 2.66s	remaining: 17.6s
# 589:	learn: 0.1716586	total: 2.66s	remaining: 17.6s
# 590:	learn: 0.1715215	total: 2.67s	remaining: 17.6s
# 591:	learn: 0.1713415	total: 2.67s	remaining: 17.6s
# 592:	learn: 0.1711425	total: 2.68s	remaining: 17.6s
# 593:	learn: 0.1709566	total: 2.68s	remaining: 17.6s
# 594:	learn: 0.1707782	total: 2.69s	remaining: 17.6s
# 595:	learn: 0.1705983	total: 2.69s	remaining: 17.6s
# 596:	learn: 0.1704165	total: 2.69s	remaining: 17.6s
# 597:	learn: 0.1702797	total: 2.7s	remaining: 17.6s
# 598:	learn: 0.1701075	total: 2.7s	remaining: 17.6s
# 599:	learn: 0.1699768	total: 2.71s	remaining: 17.6s
# 600:	learn: 0.1698000	total: 2.71s	remaining: 17.6s
# 601:	learn: 0.1696176	total: 2.72s	remaining: 17.6s
# 602:	learn: 0.1694457	total: 2.72s	remaining: 17.6s
# 603:	learn: 0.1692499	total: 2.73s	remaining: 17.6s
# 604:	learn: 0.1691120	total: 2.73s	remaining: 17.6s
# 605:	learn: 0.1689225	total: 2.74s	remaining: 17.6s
# 606:	learn: 0.1687694	total: 2.74s	remaining: 17.6s
# 607:	learn: 0.1686187	total: 2.75s	remaining: 17.6s
# 608:	learn: 0.1684540	total: 2.75s	remaining: 17.6s
# 609:	learn: 0.1683376	total: 2.75s	remaining: 17.6s
# 610:	learn: 0.1681841	total: 2.76s	remaining: 17.5s
# 611:	learn: 0.1680257	total: 2.76s	remaining: 17.5s
# 612:	learn: 0.1678811	total: 2.77s	remaining: 17.5s
# 613:	learn: 0.1677512	total: 2.77s	remaining: 17.5s
# 614:	learn: 0.1675899	total: 2.77s	remaining: 17.5s
# 615:	learn: 0.1674347	total: 2.78s	remaining: 17.5s
# 616:	learn: 0.1672585	total: 2.78s	remaining: 17.5s
# 617:	learn: 0.1671192	total: 2.79s	remaining: 17.5s
# 618:	learn: 0.1669501	total: 2.79s	remaining: 17.5s
# 619:	learn: 0.1668122	total: 2.8s	remaining: 17.5s
# 620:	learn: 0.1666727	total: 2.8s	remaining: 17.5s
# 621:	learn: 0.1665290	total: 2.81s	remaining: 17.5s
# 622:	learn: 0.1664260	total: 2.81s	remaining: 17.5s
# 623:	learn: 0.1662768	total: 2.82s	remaining: 17.5s
# 624:	learn: 0.1661310	total: 2.82s	remaining: 17.5s
# 625:	learn: 0.1659714	total: 2.83s	remaining: 17.5s
# 626:	learn: 0.1658757	total: 2.83s	remaining: 17.5s
# 627:	learn: 0.1657585	total: 2.83s	remaining: 17.5s
# 628:	learn: 0.1656274	total: 2.84s	remaining: 17.5s
# 629:	learn: 0.1654655	total: 2.85s	remaining: 17.5s
# 630:	learn: 0.1653537	total: 2.85s	remaining: 17.5s
# 631:	learn: 0.1652041	total: 2.86s	remaining: 17.5s
# 632:	learn: 0.1650826	total: 2.86s	remaining: 17.5s
# 633:	learn: 0.1649486	total: 2.87s	remaining: 17.5s
# 634:	learn: 0.1648038	total: 2.88s	remaining: 17.5s
# 635:	learn: 0.1646498	total: 2.88s	remaining: 17.5s
# 636:	learn: 0.1645492	total: 2.88s	remaining: 17.5s
# 637:	learn: 0.1643955	total: 2.89s	remaining: 17.5s
# 638:	learn: 0.1642945	total: 2.89s	remaining: 17.5s
# 639:	learn: 0.1641601	total: 2.9s	remaining: 17.5s
# 640:	learn: 0.1640073	total: 2.9s	remaining: 17.5s
# 641:	learn: 0.1638548	total: 2.91s	remaining: 17.5s
# 642:	learn: 0.1637288	total: 2.91s	remaining: 17.5s
# 643:	learn: 0.1635724	total: 2.91s	remaining: 17.5s
# 644:	learn: 0.1634346	total: 2.92s	remaining: 17.4s
# 645:	learn: 0.1632848	total: 2.92s	remaining: 17.4s
# 646:	learn: 0.1631793	total: 2.93s	remaining: 17.4s
# 647:	learn: 0.1630421	total: 2.93s	remaining: 17.4s
# 648:	learn: 0.1628839	total: 2.94s	remaining: 17.4s
# 649:	learn: 0.1627409	total: 2.94s	remaining: 17.4s
# 650:	learn: 0.1626254	total: 2.94s	remaining: 17.4s
# 651:	learn: 0.1625176	total: 2.95s	remaining: 17.4s
# 652:	learn: 0.1623575	total: 2.95s	remaining: 17.4s
# 653:	learn: 0.1622442	total: 2.96s	remaining: 17.4s
# 654:	learn: 0.1621205	total: 2.96s	remaining: 17.4s
# 655:	learn: 0.1619945	total: 2.97s	remaining: 17.4s
# 656:	learn: 0.1618385	total: 2.97s	remaining: 17.4s
# 657:	learn: 0.1616915	total: 2.98s	remaining: 17.4s
# 658:	learn: 0.1615625	total: 2.98s	remaining: 17.4s
# 659:	learn: 0.1614225	total: 2.98s	remaining: 17.4s
# 660:	learn: 0.1612931	total: 2.99s	remaining: 17.4s
# 661:	learn: 0.1611919	total: 2.99s	remaining: 17.4s
# 662:	learn: 0.1610692	total: 3s	remaining: 17.4s
# 663:	learn: 0.1609495	total: 3s	remaining: 17.3s
# 664:	learn: 0.1608744	total: 3.01s	remaining: 17.3s
# 665:	learn: 0.1607526	total: 3.01s	remaining: 17.3s
# 666:	learn: 0.1606356	total: 3.01s	remaining: 17.3s
# 667:	learn: 0.1605213	total: 3.02s	remaining: 17.3s
# 668:	learn: 0.1603974	total: 3.02s	remaining: 17.3s
# 669:	learn: 0.1602612	total: 3.03s	remaining: 17.3s
# 670:	learn: 0.1601469	total: 3.03s	remaining: 17.3s
# 671:	learn: 0.1600203	total: 3.03s	remaining: 17.3s
# 672:	learn: 0.1598622	total: 3.04s	remaining: 17.3s
# 673:	learn: 0.1597524	total: 3.04s	remaining: 17.2s
# 674:	learn: 0.1596343	total: 3.04s	remaining: 17.2s
# 675:	learn: 0.1595200	total: 3.04s	remaining: 17.2s
# 676:	learn: 0.1593847	total: 3.05s	remaining: 17.2s
# 677:	learn: 0.1592533	total: 3.05s	remaining: 17.2s
# 678:	learn: 0.1591286	total: 3.05s	remaining: 17.2s
# 679:	learn: 0.1590273	total: 3.06s	remaining: 17.2s
# 680:	learn: 0.1588845	total: 3.06s	remaining: 17.2s
# 681:	learn: 0.1587538	total: 3.07s	remaining: 17.2s
# 682:	learn: 0.1586345	total: 3.07s	remaining: 17.2s
# 683:	learn: 0.1585011	total: 3.08s	remaining: 17.2s
# 684:	learn: 0.1583640	total: 3.08s	remaining: 17.2s
# 685:	learn: 0.1582284	total: 3.08s	remaining: 17.1s
# 686:	learn: 0.1581113	total: 3.09s	remaining: 17.1s
# 687:	learn: 0.1579993	total: 3.09s	remaining: 17.1s
# 688:	learn: 0.1578587	total: 3.1s	remaining: 17.1s
# 689:	learn: 0.1577487	total: 3.1s	remaining: 17.1s
# 690:	learn: 0.1576397	total: 3.1s	remaining: 17.1s
# 691:	learn: 0.1575234	total: 3.11s	remaining: 17.1s
# 692:	learn: 0.1574088	total: 3.12s	remaining: 17.1s
# 693:	learn: 0.1572689	total: 3.12s	remaining: 17.1s
# 694:	learn: 0.1571468	total: 3.12s	remaining: 17.1s
# 695:	learn: 0.1570172	total: 3.13s	remaining: 17.1s
# 696:	learn: 0.1568712	total: 3.13s	remaining: 17.1s
# 697:	learn: 0.1567896	total: 3.14s	remaining: 17.1s
# 698:	learn: 0.1566883	total: 3.14s	remaining: 17.1s
# 699:	learn: 0.1565493	total: 3.15s	remaining: 17.1s
# 700:	learn: 0.1564460	total: 3.15s	remaining: 17.1s
# 701:	learn: 0.1563239	total: 3.16s	remaining: 17.1s
# 702:	learn: 0.1562015	total: 3.16s	remaining: 17.1s
# 703:	learn: 0.1560788	total: 3.17s	remaining: 17.1s
# 704:	learn: 0.1559795	total: 3.17s	remaining: 17.1s
# 705:	learn: 0.1558549	total: 3.18s	remaining: 17.1s
# 706:	learn: 0.1557630	total: 3.18s	remaining: 17.1s
# 707:	learn: 0.1556366	total: 3.19s	remaining: 17.1s
# 708:	learn: 0.1555429	total: 3.19s	remaining: 17s
# 709:	learn: 0.1554379	total: 3.19s	remaining: 17s
# 710:	learn: 0.1553426	total: 3.19s	remaining: 17s
# 711:	learn: 0.1552288	total: 3.19s	remaining: 17s
# 712:	learn: 0.1551081	total: 3.2s	remaining: 17s
# 713:	learn: 0.1550195	total: 3.2s	remaining: 17s
# 714:	learn: 0.1548778	total: 3.2s	remaining: 17s
# 715:	learn: 0.1547758	total: 3.21s	remaining: 16.9s
# 716:	learn: 0.1546627	total: 3.21s	remaining: 16.9s
# 717:	learn: 0.1545560	total: 3.21s	remaining: 16.9s
# 718:	learn: 0.1544454	total: 3.22s	remaining: 16.9s
# 719:	learn: 0.1543715	total: 3.22s	remaining: 16.9s
# 720:	learn: 0.1542635	total: 3.23s	remaining: 16.9s
# 721:	learn: 0.1541393	total: 3.23s	remaining: 16.9s
# 722:	learn: 0.1540118	total: 3.24s	remaining: 16.9s
# 723:	learn: 0.1539130	total: 3.24s	remaining: 16.9s
# 724:	learn: 0.1538360	total: 3.25s	remaining: 16.9s
# 725:	learn: 0.1537421	total: 3.25s	remaining: 16.9s
# 726:	learn: 0.1536304	total: 3.25s	remaining: 16.9s
# 727:	learn: 0.1534987	total: 3.26s	remaining: 16.9s
# 728:	learn: 0.1534047	total: 3.26s	remaining: 16.9s
# 729:	learn: 0.1533256	total: 3.27s	remaining: 16.9s
# 730:	learn: 0.1532144	total: 3.27s	remaining: 16.9s
# 731:	learn: 0.1531079	total: 3.28s	remaining: 16.9s
# 732:	learn: 0.1530165	total: 3.28s	remaining: 16.9s
# 733:	learn: 0.1529352	total: 3.29s	remaining: 16.9s
# 734:	learn: 0.1528448	total: 3.29s	remaining: 16.9s
# 735:	learn: 0.1527509	total: 3.3s	remaining: 16.9s
# 736:	learn: 0.1526547	total: 3.31s	remaining: 16.9s
# 737:	learn: 0.1525406	total: 3.31s	remaining: 16.9s
# 738:	learn: 0.1524534	total: 3.32s	remaining: 16.9s
# 739:	learn: 0.1523603	total: 3.32s	remaining: 16.9s
# 740:	learn: 0.1522583	total: 3.32s	remaining: 16.9s
# 741:	learn: 0.1521703	total: 3.33s	remaining: 16.9s
# 742:	learn: 0.1520692	total: 3.33s	remaining: 16.8s
# 743:	learn: 0.1519767	total: 3.34s	remaining: 16.8s
# 744:	learn: 0.1519095	total: 3.34s	remaining: 16.8s
# 745:	learn: 0.1517929	total: 3.35s	remaining: 16.8s
# 746:	learn: 0.1516972	total: 3.35s	remaining: 16.8s
# 747:	learn: 0.1516066	total: 3.35s	remaining: 16.8s
# 748:	learn: 0.1515102	total: 3.37s	remaining: 16.9s
# 749:	learn: 0.1514478	total: 3.38s	remaining: 16.9s
# 750:	learn: 0.1513754	total: 3.38s	remaining: 16.9s
# 751:	learn: 0.1513034	total: 3.39s	remaining: 16.9s
# 752:	learn: 0.1512044	total: 3.39s	remaining: 16.9s
# 753:	learn: 0.1511444	total: 3.4s	remaining: 16.9s
# 754:	learn: 0.1510439	total: 3.41s	remaining: 16.9s
# 755:	learn: 0.1509589	total: 3.42s	remaining: 16.9s
# 756:	learn: 0.1508510	total: 3.42s	remaining: 16.9s
# 757:	learn: 0.1507715	total: 3.43s	remaining: 16.9s
# 758:	learn: 0.1506791	total: 3.43s	remaining: 16.9s
# 759:	learn: 0.1506168	total: 3.44s	remaining: 16.9s
# 760:	learn: 0.1505574	total: 3.44s	remaining: 16.9s
# 761:	learn: 0.1504591	total: 3.44s	remaining: 16.9s
# 762:	learn: 0.1503527	total: 3.45s	remaining: 16.9s
# 763:	learn: 0.1502888	total: 3.45s	remaining: 16.9s
# 764:	learn: 0.1502174	total: 3.46s	remaining: 16.9s
# 765:	learn: 0.1501054	total: 3.46s	remaining: 16.9s
# 766:	learn: 0.1500368	total: 3.47s	remaining: 16.9s
# 767:	learn: 0.1499625	total: 3.47s	remaining: 16.9s
# 768:	learn: 0.1499155	total: 3.47s	remaining: 16.9s
# 769:	learn: 0.1498309	total: 3.48s	remaining: 16.9s
# 770:	learn: 0.1497346	total: 3.48s	remaining: 16.8s
# 771:	learn: 0.1496664	total: 3.49s	remaining: 16.8s
# 772:	learn: 0.1495839	total: 3.49s	remaining: 16.8s
# 773:	learn: 0.1495220	total: 3.5s	remaining: 16.8s
# 774:	learn: 0.1494385	total: 3.5s	remaining: 16.8s
# 775:	learn: 0.1493415	total: 3.5s	remaining: 16.8s
# 776:	learn: 0.1492745	total: 3.51s	remaining: 16.8s
# 777:	learn: 0.1491915	total: 3.51s	remaining: 16.8s
# 778:	learn: 0.1491094	total: 3.52s	remaining: 16.8s
# 779:	learn: 0.1490363	total: 3.52s	remaining: 16.8s
# 780:	learn: 0.1489584	total: 3.52s	remaining: 16.8s
# 781:	learn: 0.1489003	total: 3.53s	remaining: 16.8s
# 782:	learn: 0.1488430	total: 3.53s	remaining: 16.8s
# 783:	learn: 0.1487606	total: 3.54s	remaining: 16.8s
# 784:	learn: 0.1486822	total: 3.54s	remaining: 16.7s
# 785:	learn: 0.1485992	total: 3.54s	remaining: 16.7s
# 786:	learn: 0.1485508	total: 3.55s	remaining: 16.7s
# 787:	learn: 0.1484717	total: 3.55s	remaining: 16.7s
# 788:	learn: 0.1484089	total: 3.55s	remaining: 16.7s
# 789:	learn: 0.1483413	total: 3.56s	remaining: 16.7s
# 790:	learn: 0.1482640	total: 3.56s	remaining: 16.7s
# 791:	learn: 0.1481743	total: 3.56s	remaining: 16.7s
# 792:	learn: 0.1481011	total: 3.57s	remaining: 16.7s
# 793:	learn: 0.1480269	total: 3.57s	remaining: 16.7s
# 794:	learn: 0.1479587	total: 3.58s	remaining: 16.7s
# 795:	learn: 0.1478867	total: 3.58s	remaining: 16.7s
# 796:	learn: 0.1478192	total: 3.59s	remaining: 16.7s
# 797:	learn: 0.1477584	total: 3.59s	remaining: 16.7s
# 798:	learn: 0.1476856	total: 3.59s	remaining: 16.7s
# 799:	learn: 0.1476010	total: 3.6s	remaining: 16.6s
# 800:	learn: 0.1475293	total: 3.6s	remaining: 16.6s
# 801:	learn: 0.1474599	total: 3.61s	remaining: 16.6s
# 802:	learn: 0.1473834	total: 3.61s	remaining: 16.6s
# 803:	learn: 0.1473293	total: 3.62s	remaining: 16.6s
# 804:	learn: 0.1472645	total: 3.62s	remaining: 16.6s
# 805:	learn: 0.1472057	total: 3.63s	remaining: 16.6s
# 806:	learn: 0.1471338	total: 3.63s	remaining: 16.6s
# 807:	learn: 0.1470910	total: 3.64s	remaining: 16.6s
# 808:	learn: 0.1470288	total: 3.64s	remaining: 16.6s
# 809:	learn: 0.1469480	total: 3.65s	remaining: 16.6s
# 810:	learn: 0.1468703	total: 3.65s	remaining: 16.6s
# 811:	learn: 0.1468098	total: 3.65s	remaining: 16.6s
# 812:	learn: 0.1467484	total: 3.66s	remaining: 16.6s
# 813:	learn: 0.1466715	total: 3.66s	remaining: 16.6s
# 814:	learn: 0.1466216	total: 3.67s	remaining: 16.6s
# 815:	learn: 0.1465475	total: 3.67s	remaining: 16.6s
# 816:	learn: 0.1464947	total: 3.67s	remaining: 16.6s
# 817:	learn: 0.1464193	total: 3.68s	remaining: 16.6s
# 818:	learn: 0.1463751	total: 3.68s	remaining: 16.6s
# 819:	learn: 0.1463176	total: 3.69s	remaining: 16.6s
# 820:	learn: 0.1462624	total: 3.69s	remaining: 16.6s
# 821:	learn: 0.1462081	total: 3.7s	remaining: 16.5s
# 822:	learn: 0.1461210	total: 3.7s	remaining: 16.5s
# 823:	learn: 0.1460455	total: 3.7s	remaining: 16.5s
# 824:	learn: 0.1459736	total: 3.71s	remaining: 16.5s
# 825:	learn: 0.1458951	total: 3.71s	remaining: 16.5s
# 826:	learn: 0.1458555	total: 3.72s	remaining: 16.5s
# 827:	learn: 0.1458159	total: 3.72s	remaining: 16.5s
# 828:	learn: 0.1457485	total: 3.73s	remaining: 16.5s
# 829:	learn: 0.1456914	total: 3.73s	remaining: 16.5s
# 830:	learn: 0.1456211	total: 3.73s	remaining: 16.5s
# 831:	learn: 0.1455448	total: 3.74s	remaining: 16.5s
# 832:	learn: 0.1454930	total: 3.75s	remaining: 16.5s
# 833:	learn: 0.1454274	total: 3.75s	remaining: 16.5s
# 834:	learn: 0.1453838	total: 3.75s	remaining: 16.5s
# 835:	learn: 0.1453210	total: 3.76s	remaining: 16.5s
# 836:	learn: 0.1452286	total: 3.76s	remaining: 16.5s
# 837:	learn: 0.1451724	total: 3.77s	remaining: 16.5s
# 838:	learn: 0.1451003	total: 3.77s	remaining: 16.4s
# 839:	learn: 0.1450353	total: 3.77s	remaining: 16.4s
# 840:	learn: 0.1449490	total: 3.78s	remaining: 16.4s
# 841:	learn: 0.1448815	total: 3.78s	remaining: 16.4s
# 842:	learn: 0.1448381	total: 3.79s	remaining: 16.4s
# 843:	learn: 0.1448137	total: 3.79s	remaining: 16.4s
# 844:	learn: 0.1447548	total: 3.79s	remaining: 16.4s
# 845:	learn: 0.1446832	total: 3.8s	remaining: 16.4s
# 846:	learn: 0.1446333	total: 3.8s	remaining: 16.4s
# 847:	learn: 0.1445904	total: 3.81s	remaining: 16.4s
# 848:	learn: 0.1445559	total: 3.81s	remaining: 16.4s
# 849:	learn: 0.1444931	total: 3.82s	remaining: 16.4s
# 850:	learn: 0.1444458	total: 3.82s	remaining: 16.4s
# 851:	learn: 0.1443861	total: 3.83s	remaining: 16.4s
# 852:	learn: 0.1443151	total: 3.83s	remaining: 16.4s
# 853:	learn: 0.1442582	total: 3.84s	remaining: 16.4s
# 854:	learn: 0.1441983	total: 3.84s	remaining: 16.4s
# 855:	learn: 0.1441492	total: 3.85s	remaining: 16.4s
# 856:	learn: 0.1441020	total: 3.85s	remaining: 16.4s
# 857:	learn: 0.1440529	total: 3.85s	remaining: 16.4s
# 858:	learn: 0.1439886	total: 3.86s	remaining: 16.4s
# 859:	learn: 0.1439283	total: 3.86s	remaining: 16.3s
# 860:	learn: 0.1438780	total: 3.86s	remaining: 16.3s
# 861:	learn: 0.1438332	total: 3.87s	remaining: 16.3s
# 862:	learn: 0.1438032	total: 3.87s	remaining: 16.3s
# 863:	learn: 0.1437384	total: 3.87s	remaining: 16.3s
# 864:	learn: 0.1436771	total: 3.88s	remaining: 16.3s
# 865:	learn: 0.1436047	total: 3.88s	remaining: 16.3s
# 866:	learn: 0.1435454	total: 3.89s	remaining: 16.3s
# 867:	learn: 0.1434792	total: 3.89s	remaining: 16.3s
# 868:	learn: 0.1434424	total: 3.89s	remaining: 16.3s
# 869:	learn: 0.1433891	total: 3.9s	remaining: 16.3s
# 870:	learn: 0.1433311	total: 3.9s	remaining: 16.3s
# 871:	learn: 0.1432949	total: 3.91s	remaining: 16.3s
# 872:	learn: 0.1432448	total: 3.91s	remaining: 16.3s
# 873:	learn: 0.1431874	total: 3.92s	remaining: 16.3s
# 874:	learn: 0.1431297	total: 3.92s	remaining: 16.3s
# 875:	learn: 0.1430909	total: 3.93s	remaining: 16.2s
# 876:	learn: 0.1430402	total: 3.93s	remaining: 16.2s
# 877:	learn: 0.1429986	total: 3.94s	remaining: 16.2s
# 878:	learn: 0.1429397	total: 3.94s	remaining: 16.2s
# 879:	learn: 0.1429107	total: 3.94s	remaining: 16.2s
# 880:	learn: 0.1428589	total: 3.95s	remaining: 16.2s
# 881:	learn: 0.1428085	total: 3.95s	remaining: 16.2s
# 882:	learn: 0.1427887	total: 3.96s	remaining: 16.2s
# 883:	learn: 0.1427255	total: 3.96s	remaining: 16.2s
# 884:	learn: 0.1426798	total: 3.96s	remaining: 16.2s
# 885:	learn: 0.1426184	total: 3.97s	remaining: 16.2s
# 886:	learn: 0.1425602	total: 3.97s	remaining: 16.2s
# 887:	learn: 0.1425104	total: 3.98s	remaining: 16.2s
# 888:	learn: 0.1424706	total: 3.98s	remaining: 16.2s
# 889:	learn: 0.1424074	total: 3.98s	remaining: 16.2s
# 890:	learn: 0.1423533	total: 3.99s	remaining: 16.1s
# 891:	learn: 0.1422800	total: 3.99s	remaining: 16.1s
# 892:	learn: 0.1422290	total: 4s	remaining: 16.1s
# 893:	learn: 0.1421932	total: 4s	remaining: 16.1s
# 894:	learn: 0.1421291	total: 4.01s	remaining: 16.1s
# 895:	learn: 0.1421040	total: 4.01s	remaining: 16.1s
# 896:	learn: 0.1420787	total: 4.01s	remaining: 16.1s
# 897:	learn: 0.1420355	total: 4.02s	remaining: 16.1s
# 898:	learn: 0.1419699	total: 4.02s	remaining: 16.1s
# 899:	learn: 0.1419159	total: 4.03s	remaining: 16.1s
# 900:	learn: 0.1418812	total: 4.03s	remaining: 16.1s
# 901:	learn: 0.1418539	total: 4.04s	remaining: 16.1s
# 902:	learn: 0.1418200	total: 4.04s	remaining: 16.1s
# 903:	learn: 0.1417741	total: 4.04s	remaining: 16.1s
# 904:	learn: 0.1417181	total: 4.05s	remaining: 16.1s
# 905:	learn: 0.1416729	total: 4.05s	remaining: 16.1s
# 906:	learn: 0.1416226	total: 4.06s	remaining: 16.1s
# 907:	learn: 0.1415863	total: 4.06s	remaining: 16.1s
# 908:	learn: 0.1415420	total: 4.07s	remaining: 16.1s
# 909:	learn: 0.1414884	total: 4.07s	remaining: 16.1s
# 910:	learn: 0.1414273	total: 4.08s	remaining: 16.1s
# 911:	learn: 0.1413854	total: 4.08s	remaining: 16.1s
# 912:	learn: 0.1413277	total: 4.08s	remaining: 16s
# 913:	learn: 0.1412894	total: 4.09s	remaining: 16s
# 914:	learn: 0.1412467	total: 4.09s	remaining: 16s
# 915:	learn: 0.1411960	total: 4.1s	remaining: 16s
# ...
# 4200:	learn: 0.1021734	total: 16.1s	remaining: 1.14s
# 4201:	learn: 0.1021605	total: 16.1s	remaining: 1.14s
# 4202:	learn: 0.1021568	total: 16.1s	remaining: 1.14s
# 4203:	learn: 0.1021541	total: 16.1s	remaining: 1.13s
# 4204:	learn: 0.1021483	total: 16.1s	remaining: 1.13s
# 4205:	learn: 0.1021409	total: 16.1s	remaining: 1.13s
# 4206:	learn: 0.1021378	total: 16.1s	remaining: 1.12s
# 4207:	learn: 0.1021336	total: 16.1s	remaining: 1.12s
# 4208:	learn: 0.1021292	total: 16.1s	remaining: 1.11s
# 4209:	learn: 0.1021246	total: 16.1s	remaining: 1.11s
# 4210:	learn: 0.1021208	total: 16.1s	remaining: 1.11s
# 4211:	learn: 0.1021163	total: 16.1s	remaining: 1.1s
# 4212:	learn: 0.1021144	total: 16.1s	remaining: 1.1s
# 4213:	learn: 0.1021118	total: 16.1s	remaining: 1.09s
# 4214:	learn: 0.1021083	total: 16.1s	remaining: 1.09s
# 4215:	learn: 0.1021077	total: 16.1s	remaining: 1.09s
# 4216:	learn: 0.1021042	total: 16.2s	remaining: 1.08s
# 4217:	learn: 0.1021029	total: 16.2s	remaining: 1.08s
# 4218:	learn: 0.1021003	total: 16.2s	remaining: 1.08s
# 4219:	learn: 0.1020927	total: 16.2s	remaining: 1.07s
# 4220:	learn: 0.1020898	total: 16.2s	remaining: 1.07s
# 4221:	learn: 0.1020861	total: 16.2s	remaining: 1.06s
# 4222:	learn: 0.1020799	total: 16.2s	remaining: 1.06s
# 4223:	learn: 0.1020775	total: 16.2s	remaining: 1.06s
# 4224:	learn: 0.1020717	total: 16.2s	remaining: 1.05s
# 4225:	learn: 0.1020684	total: 16.2s	remaining: 1.05s
# 4226:	learn: 0.1020626	total: 16.2s	remaining: 1.04s
# 4227:	learn: 0.1020543	total: 16.2s	remaining: 1.04s
# 4228:	learn: 0.1020510	total: 16.2s	remaining: 1.04s
# 4229:	learn: 0.1020475	total: 16.2s	remaining: 1.03s
# 4230:	learn: 0.1020456	total: 16.2s	remaining: 1.03s
# 4231:	learn: 0.1020434	total: 16.2s	remaining: 1.03s
# 4232:	learn: 0.1020394	total: 16.2s	remaining: 1.02s
# 4233:	learn: 0.1020348	total: 16.2s	remaining: 1.02s
# 4234:	learn: 0.1020296	total: 16.2s	remaining: 1.01s
# 4235:	learn: 0.1020258	total: 16.2s	remaining: 1.01s
# 4236:	learn: 0.1020193	total: 16.2s	remaining: 1.01s
# 4237:	learn: 0.1020119	total: 16.2s	remaining: 1s
# 4238:	learn: 0.1020050	total: 16.3s	remaining: 1s
# 4239:	learn: 0.1020001	total: 16.3s	remaining: 997ms
# 4240:	learn: 0.1019979	total: 16.3s	remaining: 993ms
# 4241:	learn: 0.1019961	total: 16.3s	remaining: 989ms
# 4242:	learn: 0.1019907	total: 16.3s	remaining: 986ms
# 4243:	learn: 0.1019871	total: 16.3s	remaining: 982ms
# 4244:	learn: 0.1019840	total: 16.3s	remaining: 978ms
# 4245:	learn: 0.1019793	total: 16.3s	remaining: 974ms
# 4246:	learn: 0.1019740	total: 16.3s	remaining: 970ms
# 4247:	learn: 0.1019707	total: 16.3s	remaining: 967ms
# 4248:	learn: 0.1019692	total: 16.3s	remaining: 963ms
# 4249:	learn: 0.1019683	total: 16.3s	remaining: 959ms
# 4250:	learn: 0.1019629	total: 16.3s	remaining: 955ms
# 4251:	learn: 0.1019565	total: 16.3s	remaining: 952ms
# 4252:	learn: 0.1019526	total: 16.3s	remaining: 948ms
# 4253:	learn: 0.1019507	total: 16.3s	remaining: 944ms
# 4254:	learn: 0.1019483	total: 16.3s	remaining: 940ms
# 4255:	learn: 0.1019422	total: 16.3s	remaining: 936ms
# 4256:	learn: 0.1019362	total: 16.3s	remaining: 933ms
# 4257:	learn: 0.1019322	total: 16.3s	remaining: 929ms
# 4258:	learn: 0.1019264	total: 16.3s	remaining: 925ms
# 4259:	learn: 0.1019199	total: 16.4s	remaining: 921ms
# 4260:	learn: 0.1019111	total: 16.4s	remaining: 917ms
# 4261:	learn: 0.1019076	total: 16.4s	remaining: 914ms
# 4262:	learn: 0.1019029	total: 16.4s	remaining: 910ms
# 4263:	learn: 0.1019000	total: 16.4s	remaining: 906ms
# 4264:	learn: 0.1018970	total: 16.4s	remaining: 902ms
# 4265:	learn: 0.1018908	total: 16.4s	remaining: 898ms
# 4266:	learn: 0.1018861	total: 16.4s	remaining: 895ms
# 4267:	learn: 0.1018783	total: 16.4s	remaining: 891ms
# 4268:	learn: 0.1018765	total: 16.4s	remaining: 887ms
# 4269:	learn: 0.1018716	total: 16.4s	remaining: 883ms
# 4270:	learn: 0.1018664	total: 16.4s	remaining: 879ms
# 4271:	learn: 0.1018643	total: 16.4s	remaining: 876ms
# 4272:	learn: 0.1018593	total: 16.4s	remaining: 872ms
# 4273:	learn: 0.1018552	total: 16.4s	remaining: 868ms
# 4274:	learn: 0.1018512	total: 16.4s	remaining: 864ms
# 4275:	learn: 0.1018457	total: 16.4s	remaining: 860ms
# 4276:	learn: 0.1018395	total: 16.4s	remaining: 857ms
# 4277:	learn: 0.1018363	total: 16.4s	remaining: 853ms
# 4278:	learn: 0.1018340	total: 16.4s	remaining: 849ms
# 4279:	learn: 0.1018316	total: 16.4s	remaining: 845ms
# 4280:	learn: 0.1018276	total: 16.4s	remaining: 841ms
# 4281:	learn: 0.1018249	total: 16.5s	remaining: 838ms
# 4282:	learn: 0.1018224	total: 16.5s	remaining: 834ms
# 4283:	learn: 0.1018203	total: 16.5s	remaining: 830ms
# 4284:	learn: 0.1018183	total: 16.5s	remaining: 826ms
# 4285:	learn: 0.1018153	total: 16.5s	remaining: 822ms
# 4286:	learn: 0.1018140	total: 16.5s	remaining: 819ms
# 4287:	learn: 0.1018128	total: 16.5s	remaining: 815ms
# 4288:	learn: 0.1018103	total: 16.5s	remaining: 811ms
# 4289:	learn: 0.1018089	total: 16.5s	remaining: 807ms
# 4290:	learn: 0.1018039	total: 16.5s	remaining: 803ms
# 4291:	learn: 0.1017976	total: 16.5s	remaining: 800ms
# 4292:	learn: 0.1017961	total: 16.5s	remaining: 796ms
# 4293:	learn: 0.1017938	total: 16.5s	remaining: 792ms
# 4294:	learn: 0.1017924	total: 16.5s	remaining: 788ms
# 4295:	learn: 0.1017897	total: 16.5s	remaining: 784ms
# 4296:	learn: 0.1017781	total: 16.5s	remaining: 781ms
# 4297:	learn: 0.1017725	total: 16.5s	remaining: 777ms
# 4298:	learn: 0.1017699	total: 16.5s	remaining: 773ms
# 4299:	learn: 0.1017672	total: 16.5s	remaining: 769ms
# 4300:	learn: 0.1017640	total: 16.5s	remaining: 765ms
# 4301:	learn: 0.1017621	total: 16.5s	remaining: 762ms
# 4302:	learn: 0.1017564	total: 16.6s	remaining: 758ms
# 4303:	learn: 0.1017482	total: 16.6s	remaining: 754ms
# 4304:	learn: 0.1017421	total: 16.6s	remaining: 750ms
# 4305:	learn: 0.1017360	total: 16.6s	remaining: 746ms
# 4306:	learn: 0.1017304	total: 16.6s	remaining: 742ms
# 4307:	learn: 0.1017247	total: 16.6s	remaining: 739ms
# 4308:	learn: 0.1017227	total: 16.6s	remaining: 735ms
# 4309:	learn: 0.1017184	total: 16.6s	remaining: 731ms
# 4310:	learn: 0.1017145	total: 16.6s	remaining: 727ms
# 4311:	learn: 0.1017081	total: 16.6s	remaining: 723ms
# 4312:	learn: 0.1017014	total: 16.6s	remaining: 720ms
# 4313:	learn: 0.1016973	total: 16.6s	remaining: 716ms
# 4314:	learn: 0.1016903	total: 16.6s	remaining: 712ms
# 4315:	learn: 0.1016873	total: 16.6s	remaining: 708ms
# 4316:	learn: 0.1016856	total: 16.6s	remaining: 704ms
# 4317:	learn: 0.1016864	total: 16.6s	remaining: 701ms
# 4318:	learn: 0.1016830	total: 16.6s	remaining: 697ms
# 4319:	learn: 0.1016786	total: 16.6s	remaining: 693ms
# 4320:	learn: 0.1016745	total: 16.6s	remaining: 689ms
# 4321:	learn: 0.1016685	total: 16.6s	remaining: 685ms
# 4322:	learn: 0.1016570	total: 16.6s	remaining: 681ms
# 4323:	learn: 0.1016531	total: 16.6s	remaining: 678ms
# 4324:	learn: 0.1016486	total: 16.7s	remaining: 674ms
# 4325:	learn: 0.1016431	total: 16.7s	remaining: 670ms
# 4326:	learn: 0.1016386	total: 16.7s	remaining: 666ms
# 4327:	learn: 0.1016348	total: 16.7s	remaining: 662ms
# 4328:	learn: 0.1016331	total: 16.7s	remaining: 659ms
# 4329:	learn: 0.1016302	total: 16.7s	remaining: 655ms
# 4330:	learn: 0.1016196	total: 16.7s	remaining: 651ms
# 4331:	learn: 0.1016162	total: 16.7s	remaining: 647ms
# 4332:	learn: 0.1016129	total: 16.7s	remaining: 643ms
# 4333:	learn: 0.1016105	total: 16.7s	remaining: 640ms
# 4334:	learn: 0.1016062	total: 16.7s	remaining: 636ms
# 4335:	learn: 0.1016035	total: 16.7s	remaining: 632ms
# 4336:	learn: 0.1015995	total: 16.7s	remaining: 628ms
# 4337:	learn: 0.1015947	total: 16.7s	remaining: 624ms
# 4338:	learn: 0.1015896	total: 16.7s	remaining: 620ms
# 4339:	learn: 0.1015864	total: 16.7s	remaining: 617ms
# 4340:	learn: 0.1015819	total: 16.7s	remaining: 613ms
# 4341:	learn: 0.1015789	total: 16.7s	remaining: 609ms
# 4342:	learn: 0.1015776	total: 16.7s	remaining: 605ms
# 4343:	learn: 0.1015709	total: 16.7s	remaining: 601ms
# 4344:	learn: 0.1015647	total: 16.7s	remaining: 597ms
# 4345:	learn: 0.1015613	total: 16.8s	remaining: 594ms
# 4346:	learn: 0.1015598	total: 16.8s	remaining: 590ms
# 4347:	learn: 0.1015584	total: 16.8s	remaining: 586ms
# 4348:	learn: 0.1015564	total: 16.8s	remaining: 582ms
# 4349:	learn: 0.1015546	total: 16.8s	remaining: 578ms
# 4350:	learn: 0.1015491	total: 16.8s	remaining: 574ms
# 4351:	learn: 0.1015462	total: 16.8s	remaining: 571ms
# 4352:	learn: 0.1015445	total: 16.8s	remaining: 567ms
# 4353:	learn: 0.1015378	total: 16.8s	remaining: 563ms
# 4354:	learn: 0.1015356	total: 16.8s	remaining: 559ms
# 4355:	learn: 0.1015340	total: 16.8s	remaining: 555ms
# 4356:	learn: 0.1015308	total: 16.8s	remaining: 551ms
# 4357:	learn: 0.1015242	total: 16.8s	remaining: 548ms
# 4358:	learn: 0.1015181	total: 16.8s	remaining: 544ms
# 4359:	learn: 0.1015107	total: 16.8s	remaining: 540ms
# 4360:	learn: 0.1015050	total: 16.8s	remaining: 536ms
# 4361:	learn: 0.1015026	total: 16.8s	remaining: 532ms
# 4362:	learn: 0.1014985	total: 16.8s	remaining: 529ms
# 4363:	learn: 0.1014936	total: 16.8s	remaining: 525ms
# 4364:	learn: 0.1014865	total: 16.8s	remaining: 521ms
# 4365:	learn: 0.1014813	total: 16.8s	remaining: 517ms
# 4366:	learn: 0.1014789	total: 16.9s	remaining: 513ms
# 4367:	learn: 0.1014750	total: 16.9s	remaining: 509ms
# 4368:	learn: 0.1014717	total: 16.9s	remaining: 505ms
# 4369:	learn: 0.1014674	total: 16.9s	remaining: 502ms
# 4370:	learn: 0.1014604	total: 16.9s	remaining: 498ms
# 4371:	learn: 0.1014552	total: 16.9s	remaining: 494ms
# 4372:	learn: 0.1014473	total: 16.9s	remaining: 490ms
# 4373:	learn: 0.1014413	total: 16.9s	remaining: 486ms
# 4374:	learn: 0.1014379	total: 16.9s	remaining: 482ms
# 4375:	learn: 0.1014356	total: 16.9s	remaining: 479ms
# 4376:	learn: 0.1014344	total: 16.9s	remaining: 475ms
# 4377:	learn: 0.1014266	total: 16.9s	remaining: 471ms
# 4378:	learn: 0.1014243	total: 16.9s	remaining: 467ms
# 4379:	learn: 0.1014218	total: 16.9s	remaining: 463ms
# 4380:	learn: 0.1014158	total: 16.9s	remaining: 459ms
# 4381:	learn: 0.1014125	total: 16.9s	remaining: 456ms
# 4382:	learn: 0.1014089	total: 16.9s	remaining: 452ms
# 4383:	learn: 0.1014031	total: 16.9s	remaining: 448ms
# 4384:	learn: 0.1013990	total: 16.9s	remaining: 444ms
# 4385:	learn: 0.1013879	total: 16.9s	remaining: 440ms
# 4386:	learn: 0.1013870	total: 16.9s	remaining: 436ms
# 4387:	learn: 0.1013837	total: 16.9s	remaining: 433ms
# 4388:	learn: 0.1013797	total: 16.9s	remaining: 429ms
# 4389:	learn: 0.1013772	total: 17s	remaining: 425ms
# 4390:	learn: 0.1013720	total: 17s	remaining: 421ms
# 4391:	learn: 0.1013679	total: 17s	remaining: 417ms
# 4392:	learn: 0.1013580	total: 17s	remaining: 413ms
# 4393:	learn: 0.1013544	total: 17s	remaining: 409ms
# 4394:	learn: 0.1013494	total: 17s	remaining: 405ms
# 4395:	learn: 0.1013441	total: 17s	remaining: 401ms
# 4396:	learn: 0.1013373	total: 17s	remaining: 398ms
# 4397:	learn: 0.1013318	total: 17s	remaining: 394ms
# 4398:	learn: 0.1013285	total: 17s	remaining: 390ms
# 4399:	learn: 0.1013252	total: 17s	remaining: 386ms
# 4400:	learn: 0.1013213	total: 17s	remaining: 382ms
# 4401:	learn: 0.1013168	total: 17s	remaining: 378ms
# 4402:	learn: 0.1013150	total: 17s	remaining: 374ms
# 4403:	learn: 0.1013118	total: 17s	remaining: 371ms
# 4404:	learn: 0.1013079	total: 17s	remaining: 367ms
# 4405:	learn: 0.1013040	total: 17s	remaining: 363ms
# 4406:	learn: 0.1012975	total: 17s	remaining: 359ms
# 4407:	learn: 0.1012937	total: 17s	remaining: 355ms
# 4408:	learn: 0.1012900	total: 17s	remaining: 351ms
# 4409:	learn: 0.1012867	total: 17s	remaining: 347ms
# 4410:	learn: 0.1012815	total: 17s	remaining: 344ms
# 4411:	learn: 0.1012769	total: 17s	remaining: 340ms
# 4412:	learn: 0.1012737	total: 17s	remaining: 336ms
# 4413:	learn: 0.1012637	total: 17s	remaining: 332ms
# 4414:	learn: 0.1012553	total: 17s	remaining: 328ms
# 4415:	learn: 0.1012515	total: 17s	remaining: 324ms
# 4416:	learn: 0.1012495	total: 17s	remaining: 320ms
# 4417:	learn: 0.1012470	total: 17.1s	remaining: 316ms
# 4418:	learn: 0.1012400	total: 17.1s	remaining: 313ms
# 4419:	learn: 0.1012349	total: 17.1s	remaining: 309ms
# 4420:	learn: 0.1012326	total: 17.1s	remaining: 305ms
# 4421:	learn: 0.1012312	total: 17.1s	remaining: 301ms
# 4422:	learn: 0.1012284	total: 17.1s	remaining: 297ms
# 4423:	learn: 0.1012227	total: 17.1s	remaining: 293ms
# 4424:	learn: 0.1012192	total: 17.1s	remaining: 290ms
# 4425:	learn: 0.1012157	total: 17.1s	remaining: 286ms
# 4426:	learn: 0.1012106	total: 17.1s	remaining: 282ms
# 4427:	learn: 0.1012093	total: 17.1s	remaining: 278ms
# 4428:	learn: 0.1012057	total: 17.1s	remaining: 274ms
# 4429:	learn: 0.1012039	total: 17.1s	remaining: 270ms
# 4430:	learn: 0.1012000	total: 17.1s	remaining: 267ms
# 4431:	learn: 0.1011964	total: 17.1s	remaining: 263ms
# 4432:	learn: 0.1011866	total: 17.1s	remaining: 259ms
# 4433:	learn: 0.1011815	total: 17.1s	remaining: 255ms
# 4434:	learn: 0.1011769	total: 17.1s	remaining: 251ms
# 4435:	learn: 0.1011714	total: 17.1s	remaining: 247ms
# 4436:	learn: 0.1011690	total: 17.1s	remaining: 243ms
# 4437:	learn: 0.1011653	total: 17.1s	remaining: 240ms
# 4438:	learn: 0.1011603	total: 17.2s	remaining: 236ms
# 4439:	learn: 0.1011581	total: 17.2s	remaining: 232ms
# 4440:	learn: 0.1011558	total: 17.2s	remaining: 228ms
# 4441:	learn: 0.1011518	total: 17.2s	remaining: 224ms
# 4442:	learn: 0.1011487	total: 17.2s	remaining: 220ms
# 4443:	learn: 0.1011412	total: 17.2s	remaining: 216ms
# 4444:	learn: 0.1011396	total: 17.2s	remaining: 213ms
# 4445:	learn: 0.1011345	total: 17.2s	remaining: 209ms
# 4446:	learn: 0.1011293	total: 17.2s	remaining: 205ms
# 4447:	learn: 0.1011240	total: 17.2s	remaining: 201ms
# 4448:	learn: 0.1011203	total: 17.2s	remaining: 197ms
# 4449:	learn: 0.1011171	total: 17.2s	remaining: 193ms
# 4450:	learn: 0.1011131	total: 17.2s	remaining: 189ms
# 4451:	learn: 0.1011082	total: 17.2s	remaining: 186ms
# 4452:	learn: 0.1011031	total: 17.2s	remaining: 182ms
# 4453:	learn: 0.1011011	total: 17.2s	remaining: 178ms
# 4454:	learn: 0.1010976	total: 17.2s	remaining: 174ms
# 4455:	learn: 0.1010965	total: 17.2s	remaining: 170ms
# 4456:	learn: 0.1010920	total: 17.2s	remaining: 166ms
# 4457:	learn: 0.1010877	total: 17.2s	remaining: 162ms
# 4458:	learn: 0.1010845	total: 17.2s	remaining: 159ms
# 4459:	learn: 0.1010811	total: 17.3s	remaining: 155ms
# 4460:	learn: 0.1010778	total: 17.3s	remaining: 151ms
# 4461:	learn: 0.1010686	total: 17.3s	remaining: 147ms
# 4462:	learn: 0.1010659	total: 17.3s	remaining: 143ms
# 4463:	learn: 0.1010593	total: 17.3s	remaining: 139ms
# 4464:	learn: 0.1010552	total: 17.3s	remaining: 135ms
# 4465:	learn: 0.1010534	total: 17.3s	remaining: 132ms
# 4466:	learn: 0.1010488	total: 17.3s	remaining: 128ms
# 4467:	learn: 0.1010406	total: 17.3s	remaining: 124ms
# 4468:	learn: 0.1010354	total: 17.3s	remaining: 120ms
# 4469:	learn: 0.1010334	total: 17.3s	remaining: 116ms
# 4470:	learn: 0.1010311	total: 17.3s	remaining: 112ms
# 4471:	learn: 0.1010254	total: 17.3s	remaining: 108ms
# 4472:	learn: 0.1010196	total: 17.3s	remaining: 105ms
# 4473:	learn: 0.1010193	total: 17.3s	remaining: 101ms
# 4474:	learn: 0.1010147	total: 17.3s	remaining: 96.8ms
# 4475:	learn: 0.1010119	total: 17.3s	remaining: 92.9ms
# 4476:	learn: 0.1010041	total: 17.3s	remaining: 89ms
# 4477:	learn: 0.1010005	total: 17.3s	remaining: 85.2ms
# 4478:	learn: 0.1009975	total: 17.3s	remaining: 81.3ms
# 4479:	learn: 0.1009941	total: 17.3s	remaining: 77.4ms
# 4480:	learn: 0.1009879	total: 17.3s	remaining: 73.6ms
# 4481:	learn: 0.1009806	total: 17.4s	remaining: 69.7ms
# 4482:	learn: 0.1009782	total: 17.4s	remaining: 65.8ms
# 4483:	learn: 0.1009734	total: 17.4s	remaining: 61.9ms
# 4484:	learn: 0.1009692	total: 17.4s	remaining: 58.1ms
# 4485:	learn: 0.1009647	total: 17.4s	remaining: 54.2ms
# 4486:	learn: 0.1009616	total: 17.4s	remaining: 50.3ms
# 4487:	learn: 0.1009560	total: 17.4s	remaining: 46.5ms
# 4488:	learn: 0.1009540	total: 17.4s	remaining: 42.6ms
# 4489:	learn: 0.1009533	total: 17.4s	remaining: 38.7ms
# 4490:	learn: 0.1009516	total: 17.4s	remaining: 34.9ms
# 4491:	learn: 0.1009481	total: 17.4s	remaining: 31ms
# 4492:	learn: 0.1009352	total: 17.4s	remaining: 27.1ms
# 4493:	learn: 0.1009319	total: 17.4s	remaining: 23.2ms
# 4494:	learn: 0.1009286	total: 17.4s	remaining: 19.4ms
# 4495:	learn: 0.1009227	total: 17.4s	remaining: 15.5ms
# 4496:	learn: 0.1009205	total: 17.4s	remaining: 11.6ms
# 4497:	learn: 0.1009128	total: 17.4s	remaining: 7.75ms
# 4498:	learn: 0.1009022	total: 17.4s	remaining: 3.87ms
# 4499:	learn: 0.1009002	total: 17.4s	remaining: 0us
# RMSE = 244867.13, MAE = 147368.94, R-sq = 0.95, MAPE = 0.14
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = np.round((final_model.predict(stacked_features_test)/1000))*1000

sample_submission = pd.read_csv('sample_submission.csv')
sample_submission['price'] =  y_pred
sample_submission.to_csv(f'submission_stack_v1.csv', index=False)

sample_submission.head(10)
# Out:
#    id      price
# 0   0  1498000.0
# 1   1  2217000.0
# 2   2  1038000.0
# 3   3  2006000.0
# 4   4  5568000.0
# 5   5  1569000.0
# 6   6  1009000.0
# 7   7   653000.0
# 8   8  1199000.0
# 9   9  1268000.0
